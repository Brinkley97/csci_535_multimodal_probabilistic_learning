# %% [markdown]
# # Extract Features with ResNet

# %%
# !pip3 install datasets

# %%
import os
import sys
import csv
import pickle
import torch

import pandas as pd
import numpy as np

from transformers import AutoImageProcessor, ResNetModel
from datasets import load_dataset
from PIL import Image

# %% [markdown]
# # Load Data

# %%
BASE = '/Users/brinkley97/Documents/development/'
CLASS_PATH = 'classes/csci_535_multimodal_probabilistic_learning/'
DATASET_PATH = 'datasets/project/'

# %%
def load_data(file):
    original_data = pd.read_csv(file)
    # original_data = pd.DataFrame(file)
    copy_of_data = original_data.copy()
    return copy_of_data

# %%
file_paths_crema_d = BASE + CLASS_PATH + DATASET_PATH + 'crema_d/all_paths_to_crema_d_faces.zip'
file_paths_msp_t = BASE + CLASS_PATH + DATASET_PATH + 'msp_t/all_paths_to_msp_t_faces.zip'

# %%
dataset_paths_copy_crema_d = load_data(file_paths_crema_d)

# %%
dataset_paths_copy_crema_d
# Out:
#       Unnamed: 0                                            crema_d
# 0              0  /Users/brinkley97/Documents/development/classe...
# 1              1  /Users/brinkley97/Documents/development/classe...
# 2              2  /Users/brinkley97/Documents/development/classe...
# 3              3  /Users/brinkley97/Documents/development/classe...
# 4              4  /Users/brinkley97/Documents/development/classe...
# ...          ...                                                ...
# 7437        7437  /Users/brinkley97/Documents/development/classe...
# 7438        7438  /Users/brinkley97/Documents/development/classe...
# 7439        7439  /Users/brinkley97/Documents/development/classe...
# 7440        7440  /Users/brinkley97/Documents/development/classe...
# 7441        7441  /Users/brinkley97/Documents/development/classe...
#
# [7442 rows x 2 columns]

# %%
dataset_paths_copy_msp_t = load_data(file_paths_msp_t)

# %%
dataset_paths_copy_msp_t

# %% [markdown]
# # ResNet

# %%
image_processor = AutoImageProcessor.from_pretrained("microsoft/resnet-50")
model = ResNetModel.from_pretrained("microsoft/resnet-50")
# Out:
# Could not find image processor class in the image processor config or the model config. Loading based on pattern matching with the model's feature extractor configuration.
# Some weights of the model checkpoint at microsoft/resnet-50 were not used when initializing ResNetModel: ['classifier.1.weight', 'classifier.1.bias']
# - This IS expected if you are initializing ResNetModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ResNetModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %% [markdown]
# # Extract Features

# %%
def write_list(list_to_save, file):
    
    # store list in binary file so 'wb' mode
    with open(file, 'wb') as fp:
        pickle.dump(list_to_save, fp)
        # print('Done writing list into a binary file')

# %%
def extract_features(path_to_folders, store_extracted_features_file):
    """
    """
    len(path_to_folders)
    
    store_extracted_features_msp_t = []
    store_folder_extracted_features = []

    for path_to_folders_idx in range(len(path_to_folders)):
        path_to_face_folder = path_to_folders[path_to_folders_idx]
        print(path_to_folders_idx, path_to_face_folder)
        
        single_folder_all_faces = os.listdir(path_to_face_folder)
        
       
        for single_folder_all_faces_idx in range(len(single_folder_all_faces)):
            image_name = single_folder_all_faces[single_folder_all_faces_idx]

            path_to_image = path_to_face_folder + image_name
            image = Image.open(path_to_image)

            # inputs = feature_extractor(images=image, return_tensors="pt")
            # outputs = model(**inputs)
            # last_hidden_states = outputs.last_hidden_state 
            
            inputs = image_processor(image, return_tensors="pt")
            
            with torch.no_grad():
                outputs = model(**inputs)

            last_hidden_states = outputs.last_hidden_state
            
            
            store_folder_extracted_features.append(last_hidden_states)
            
        store_extracted_features_msp_t.append(store_folder_extracted_features)
        write_list(store_extracted_features_msp_t, store_extracted_features_file)
    
    return store_extracted_features_msp_t

# %%
save_resnet_extracted_features_crema_d = BASE + CLASS_PATH + DATASET_PATH + 'crema_d/extracted_features_crema_d/save_resnet_extracted_features_crema_d'
save_resnet_extracted_features_crema_d
# Out:
# '/Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/extracted_features_crema_d/save_resnet_extracted_features_crema_d'

# %%
crema_d_faces = dataset_paths_copy_crema_d['crema_d']
list_crema_d_faces = list(crema_d_faces)
# list_crema_d_faces

# %%
# extracted_features_crema_d = extract_features(list_crema_d_faces, save_resnet_extracted_features_crema_d)

# %%
subset = BASE + CLASS_PATH + DATASET_PATH + 'crema_d/subset_frames_to_faces_crema_d_sub'
subset_paths = os.listdir(subset)
subset_paths.sort()
type(subset_paths), len(subset_paths)
# subset_paths
# Out:
# (list, 6150)

# %%
build_subset_paths = []
for idx in range(len(subset_paths)):
    folder = subset_paths[idx]
    # print(folder)
    
    build_path = subset + '/' + folder + '/'
    
    build_subset_paths.append(build_path)
    
    # print()

# %%
len(build_subset_paths)
# Out:
# 6150

# %%
# build_subset_paths

# %%
extracted_features_crema_d = extract_features(build_subset_paths, save_resnet_extracted_features_crema_d)
# Out:
# 0 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_DFA_ANG_XX_frames_to_cropped_face_subset/
# 1 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_DFA_DIS_XX_frames_to_cropped_face_subset/
# 2 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_DFA_FEA_XX_frames_to_cropped_face_subset/
# 3 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_DFA_HAP_XX_frames_to_cropped_face_subset/
# 4 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_DFA_NEU_XX_frames_to_cropped_face_subset/
# 5 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_DFA_SAD_XX_frames_to_cropped_face_subset/
# 6 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_IEO_ANG_HI_frames_to_cropped_face_subset/
# 7 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_IEO_ANG_MD_frames_to_cropped_face_subset/
# 8 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_IEO_DIS_HI_frames_to_cropped_face_subset/
# 9 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_IEO_DIS_MD_frames_to_cropped_face_subset/
# 10 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_IEO_FEA_LO_frames_to_cropped_face_subset/
# 11 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_IEO_FEA_MD_frames_to_cropped_face_subset/
# 12 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_IEO_HAP_HI_frames_to_cropped_face_subset/
# 13 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_IEO_HAP_LO_frames_to_cropped_face_subset/
# 14 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_IEO_HAP_MD_frames_to_cropped_face_subset/
# 15 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_IEO_NEU_XX_frames_to_cropped_face_subset/
# 16 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_IEO_SAD_HI_frames_to_cropped_face_subset/
# 17 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_IEO_SAD_MD_frames_to_cropped_face_subset/
# 18 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_IOM_ANG_XX_frames_to_cropped_face_subset/
# 19 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_IOM_DIS_XX_frames_to_cropped_face_subset/
# 20 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_IOM_FEA_XX_frames_to_cropped_face_subset/
# 21 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_IOM_HAP_XX_frames_to_cropped_face_subset/
# 22 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_IOM_NEU_XX_frames_to_cropped_face_subset/
# 23 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_IOM_SAD_XX_frames_to_cropped_face_subset/
# 24 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_ITH_ANG_XX_frames_to_cropped_face_subset/
# 25 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_ITH_DIS_XX_frames_to_cropped_face_subset/
# 26 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_ITH_FEA_XX_frames_to_cropped_face_subset/
# 27 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_ITH_HAP_XX_frames_to_cropped_face_subset/
# 28 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_ITH_NEU_XX_frames_to_cropped_face_subset/
# 29 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_ITH_SAD_XX_frames_to_cropped_face_subset/
# 30 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_ITS_ANG_XX_frames_to_cropped_face_subset/
# 31 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_ITS_DIS_XX_frames_to_cropped_face_subset/
# 32 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_ITS_HAP_XX_frames_to_cropped_face_subset/
# 33 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_ITS_NEU_XX_frames_to_cropped_face_subset/
# 34 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_ITS_SAD_XX_frames_to_cropped_face_subset/
# 35 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_IWL_ANG_XX_frames_to_cropped_face_subset/
# 36 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_IWL_DIS_XX_frames_to_cropped_face_subset/
# 37 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_IWL_FEA_XX_frames_to_cropped_face_subset/
# 38 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_IWL_HAP_XX_frames_to_cropped_face_subset/
# 39 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_IWL_NEU_XX_frames_to_cropped_face_subset/
# 40 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_IWL_SAD_XX_frames_to_cropped_face_subset/
# 41 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_IWW_ANG_XX_frames_to_cropped_face_subset/
# 42 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_IWW_DIS_XX_frames_to_cropped_face_subset/
# 43 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_IWW_FEA_XX_frames_to_cropped_face_subset/
# 44 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_IWW_HAP_XX_frames_to_cropped_face_subset/
# 45 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_IWW_NEU_XX_frames_to_cropped_face_subset/
# 46 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_IWW_SAD_XX_frames_to_cropped_face_subset/
# 47 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_MTI_ANG_XX_frames_to_cropped_face_subset/
# 48 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_MTI_DIS_XX_frames_to_cropped_face_subset/
# 49 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_MTI_FEA_XX_frames_to_cropped_face_subset/
# 50 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_MTI_SAD_XX_frames_to_cropped_face_subset/
# 51 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_TAI_ANG_XX_frames_to_cropped_face_subset/
# 52 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_TAI_DIS_XX_frames_to_cropped_face_subset/
# 53 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_TAI_FEA_XX_frames_to_cropped_face_subset/
# 54 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_TAI_HAP_XX_frames_to_cropped_face_subset/
# 55 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_TAI_NEU_XX_frames_to_cropped_face_subset/
# 56 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_TAI_SAD_XX_frames_to_cropped_face_subset/
# 57 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_TIE_ANG_XX_frames_to_cropped_face_subset/
# 58 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_TIE_DIS_XX_frames_to_cropped_face_subset/
# 59 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_TIE_FEA_XX_frames_to_cropped_face_subset/
# 60 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_TIE_SAD_XX_frames_to_cropped_face_subset/
# 61 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_TSI_FEA_XX_frames_to_cropped_face_subset/
# 62 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_TSI_HAP_XX_frames_to_cropped_face_subset/
# 63 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_TSI_NEU_XX_frames_to_cropped_face_subset/
# 64 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_WSI_ANG_XX_frames_to_cropped_face_subset/
# 65 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_WSI_DIS_XX_frames_to_cropped_face_subset/
# 66 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_WSI_HAP_XX_frames_to_cropped_face_subset/
# 67 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_WSI_NEU_XX_frames_to_cropped_face_subset/
# 68 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1001_WSI_SAD_XX_frames_to_cropped_face_subset/
# 69 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_DFA_ANG_XX_frames_to_cropped_face_subset/
# 70 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_DFA_DIS_XX_frames_to_cropped_face_subset/
# 71 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_DFA_FEA_XX_frames_to_cropped_face_subset/
# 72 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_DFA_HAP_XX_frames_to_cropped_face_subset/
# 73 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_DFA_SAD_XX_frames_to_cropped_face_subset/
# 74 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_IEO_ANG_LO_frames_to_cropped_face_subset/
# 75 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_IEO_ANG_MD_frames_to_cropped_face_subset/
# 76 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_IEO_DIS_LO_frames_to_cropped_face_subset/
# 77 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_IEO_DIS_MD_frames_to_cropped_face_subset/
# 78 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_IEO_FEA_HI_frames_to_cropped_face_subset/
# 79 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_IEO_FEA_MD_frames_to_cropped_face_subset/
# 80 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_IEO_HAP_HI_frames_to_cropped_face_subset/
# 81 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_IEO_HAP_LO_frames_to_cropped_face_subset/
# 82 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_IEO_HAP_MD_frames_to_cropped_face_subset/
# 83 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_IEO_NEU_XX_frames_to_cropped_face_subset/
# 84 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_IEO_SAD_HI_frames_to_cropped_face_subset/
# 85 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_IEO_SAD_LO_frames_to_cropped_face_subset/
# 86 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_IEO_SAD_MD_frames_to_cropped_face_subset/
# 87 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_IOM_ANG_XX_frames_to_cropped_face_subset/
# 88 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_IOM_DIS_XX_frames_to_cropped_face_subset/
# 89 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_IOM_FEA_XX_frames_to_cropped_face_subset/
# 90 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_IOM_HAP_XX_frames_to_cropped_face_subset/
# 91 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_IOM_SAD_XX_frames_to_cropped_face_subset/
# 92 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_ITH_FEA_XX_frames_to_cropped_face_subset/
# 93 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_ITH_HAP_XX_frames_to_cropped_face_subset/
# 94 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_ITH_NEU_XX_frames_to_cropped_face_subset/
# 95 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_ITS_FEA_XX_frames_to_cropped_face_subset/
# 96 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_ITS_HAP_XX_frames_to_cropped_face_subset/
# 97 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_ITS_NEU_XX_frames_to_cropped_face_subset/
# 98 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_IWL_FEA_XX_frames_to_cropped_face_subset/
# 99 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_IWL_HAP_XX_frames_to_cropped_face_subset/
# 100 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_IWL_NEU_XX_frames_to_cropped_face_subset/
# 101 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_IWW_FEA_XX_frames_to_cropped_face_subset/
# 102 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_IWW_HAP_XX_frames_to_cropped_face_subset/
# 103 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_IWW_NEU_XX_frames_to_cropped_face_subset/
# 104 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_MTI_ANG_XX_frames_to_cropped_face_subset/
# 105 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_MTI_DIS_XX_frames_to_cropped_face_subset/
# 106 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_MTI_FEA_XX_frames_to_cropped_face_subset/
# 107 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_MTI_HAP_XX_frames_to_cropped_face_subset/
# 108 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_MTI_NEU_XX_frames_to_cropped_face_subset/
# 109 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_MTI_SAD_XX_frames_to_cropped_face_subset/
# 110 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_TAI_ANG_XX_frames_to_cropped_face_subset/
# 111 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_TAI_DIS_XX_frames_to_cropped_face_subset/
# 112 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_TAI_FEA_XX_frames_to_cropped_face_subset/
# 113 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_TAI_SAD_XX_frames_to_cropped_face_subset/
# 114 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_TIE_ANG_XX_frames_to_cropped_face_subset/
# 115 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_TIE_DIS_XX_frames_to_cropped_face_subset/
# 116 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_TIE_FEA_XX_frames_to_cropped_face_subset/
# 117 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_TIE_HAP_XX_frames_to_cropped_face_subset/
# 118 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_TIE_SAD_XX_frames_to_cropped_face_subset/
# 119 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_TSI_ANG_XX_frames_to_cropped_face_subset/
# 120 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_TSI_DIS_XX_frames_to_cropped_face_subset/
# 121 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_TSI_FEA_XX_frames_to_cropped_face_subset/
# 122 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_TSI_HAP_XX_frames_to_cropped_face_subset/
# 123 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_TSI_NEU_XX_frames_to_cropped_face_subset/
# 124 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_TSI_SAD_XX_frames_to_cropped_face_subset/
# 125 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_WSI_FEA_XX_frames_to_cropped_face_subset/
# 126 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_WSI_HAP_XX_frames_to_cropped_face_subset/
# 127 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1002_WSI_NEU_XX_frames_to_cropped_face_subset/
# 128 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_DFA_ANG_XX_frames_to_cropped_face_subset/
# 129 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_DFA_DIS_XX_frames_to_cropped_face_subset/
# 130 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_DFA_FEA_XX_frames_to_cropped_face_subset/
# 131 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_DFA_HAP_XX_frames_to_cropped_face_subset/
# 132 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_DFA_NEU_XX_frames_to_cropped_face_subset/
# 133 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_DFA_SAD_XX_frames_to_cropped_face_subset/
# 134 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_IEO_ANG_HI_frames_to_cropped_face_subset/
# 135 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_IEO_ANG_MD_frames_to_cropped_face_subset/
# 136 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_IEO_DIS_HI_frames_to_cropped_face_subset/
# 137 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_IEO_DIS_MD_frames_to_cropped_face_subset/
# 138 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_IEO_FEA_LO_frames_to_cropped_face_subset/
# 139 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_IEO_FEA_MD_frames_to_cropped_face_subset/
# 140 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_IEO_HAP_HI_frames_to_cropped_face_subset/
# 141 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_IEO_HAP_LO_frames_to_cropped_face_subset/
# 142 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_IEO_NEU_XX_frames_to_cropped_face_subset/
# 143 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_IEO_SAD_HI_frames_to_cropped_face_subset/
# 144 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_IEO_SAD_LO_frames_to_cropped_face_subset/
# 145 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_IEO_SAD_MD_frames_to_cropped_face_subset/
# 146 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_IOM_ANG_XX_frames_to_cropped_face_subset/
# 147 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_IOM_DIS_XX_frames_to_cropped_face_subset/
# 148 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_IOM_FEA_XX_frames_to_cropped_face_subset/
# 149 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_IOM_HAP_XX_frames_to_cropped_face_subset/
# 150 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_IOM_NEU_XX_frames_to_cropped_face_subset/
# 151 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_IOM_SAD_XX_frames_to_cropped_face_subset/
# 152 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_ITH_ANG_XX_frames_to_cropped_face_subset/
# 153 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_ITH_DIS_XX_frames_to_cropped_face_subset/
# 154 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_ITH_HAP_XX_frames_to_cropped_face_subset/
# 155 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_ITH_NEU_XX_frames_to_cropped_face_subset/
# 156 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_ITH_SAD_XX_frames_to_cropped_face_subset/
# 157 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_ITS_ANG_XX_frames_to_cropped_face_subset/
# 158 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_ITS_DIS_XX_frames_to_cropped_face_subset/
# 159 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_ITS_HAP_XX_frames_to_cropped_face_subset/
# 160 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_ITS_NEU_XX_frames_to_cropped_face_subset/
# 161 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_ITS_SAD_XX_frames_to_cropped_face_subset/
# 162 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_IWL_ANG_XX_frames_to_cropped_face_subset/
# 163 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_IWL_DIS_XX_frames_to_cropped_face_subset/
# 164 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_IWL_HAP_XX_frames_to_cropped_face_subset/
# 165 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_IWL_NEU_XX_frames_to_cropped_face_subset/
# 166 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_IWL_SAD_XX_frames_to_cropped_face_subset/
# 167 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_IWW_ANG_XX_frames_to_cropped_face_subset/
# 168 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_IWW_DIS_XX_frames_to_cropped_face_subset/
# 169 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_IWW_HAP_XX_frames_to_cropped_face_subset/
# 170 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_IWW_NEU_XX_frames_to_cropped_face_subset/
# 171 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_IWW_SAD_XX_frames_to_cropped_face_subset/
# 172 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_MTI_ANG_XX_frames_to_cropped_face_subset/
# 173 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_MTI_DIS_XX_frames_to_cropped_face_subset/
# 174 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_MTI_FEA_XX_frames_to_cropped_face_subset/
# 175 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_MTI_SAD_XX_frames_to_cropped_face_subset/
# 176 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_TAI_ANG_XX_frames_to_cropped_face_subset/
# 177 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_TAI_DIS_XX_frames_to_cropped_face_subset/
# 178 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_TAI_FEA_XX_frames_to_cropped_face_subset/
# 179 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_TAI_HAP_XX_frames_to_cropped_face_subset/
# 180 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_TAI_NEU_XX_frames_to_cropped_face_subset/
# 181 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_TAI_SAD_XX_frames_to_cropped_face_subset/
# 182 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_TIE_ANG_XX_frames_to_cropped_face_subset/
# 183 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_TIE_DIS_XX_frames_to_cropped_face_subset/
# 184 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_TIE_FEA_XX_frames_to_cropped_face_subset/
# 185 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_TIE_SAD_XX_frames_to_cropped_face_subset/
# 186 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_TSI_ANG_XX_frames_to_cropped_face_subset/
# 187 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_TSI_DIS_XX_frames_to_cropped_face_subset/
# 188 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_TSI_FEA_XX_frames_to_cropped_face_subset/
# 189 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_TSI_HAP_XX_frames_to_cropped_face_subset/
# 190 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_TSI_NEU_XX_frames_to_cropped_face_subset/
# 191 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_WSI_ANG_XX_frames_to_cropped_face_subset/
# 192 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_WSI_DIS_XX_frames_to_cropped_face_subset/
# 193 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_WSI_HAP_XX_frames_to_cropped_face_subset/
# 194 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_WSI_NEU_XX_frames_to_cropped_face_subset/
# 195 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1003_WSI_SAD_XX_frames_to_cropped_face_subset/
# 196 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1004_DFA_ANG_XX_frames_to_cropped_face_subset/
# 197 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1004_DFA_DIS_XX_frames_to_cropped_face_subset/
# 198 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1004_DFA_FEA_XX_frames_to_cropped_face_subset/
# 199 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1004_DFA_HAP_XX_frames_to_cropped_face_subset/
# 200 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1004_DFA_NEU_XX_frames_to_cropped_face_subset/
# 201 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1004_IEO_ANG_HI_frames_to_cropped_face_subset/
# 202 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1004_IEO_ANG_LO_frames_to_cropped_face_subset/
# 203 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1004_IEO_ANG_MD_frames_to_cropped_face_subset/
# 204 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1004_IEO_DIS_HI_frames_to_cropped_face_subset/
# 205 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1004_IEO_DIS_LO_frames_to_cropped_face_subset/
# 206 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1004_IEO_DIS_MD_frames_to_cropped_face_subset/
# 207 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1004_IEO_FEA_HI_frames_to_cropped_face_subset/
# 208 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1004_IEO_FEA_LO_frames_to_cropped_face_subset/
# 209 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1004_IEO_HAP_HI_frames_to_cropped_face_subset/
# 210 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1004_IEO_HAP_LO_frames_to_cropped_face_subset/
# 211 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1004_IEO_HAP_MD_frames_to_cropped_face_subset/
# 212 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1004_IEO_NEU_XX_frames_to_cropped_face_subset/
# 213 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1004_IEO_SAD_HI_frames_to_cropped_face_subset/
# 214 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1004_IEO_SAD_LO_frames_to_cropped_face_subset/
# 215 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1004_IEO_SAD_MD_frames_to_cropped_face_subset/
# 216 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1004_IOM_ANG_XX_frames_to_cropped_face_subset/
# 217 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1004_IOM_DIS_XX_frames_to_cropped_face_subset/
# 218 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1004_IOM_FEA_XX_frames_to_cropped_face_subset/
# 219 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1004_IOM_HAP_XX_frames_to_cropped_face_subset/
# 220 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1004_IOM_NEU_XX_frames_to_cropped_face_subset/
# 221 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1004_ITH_ANG_XX_frames_to_cropped_face_subset/
# 222 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1004_ITH_DIS_XX_frames_to_cropped_face_subset/
# 223 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1004_ITH_FEA_XX_frames_to_cropped_face_subset/
# 224 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1004_ITH_SAD_XX_frames_to_cropped_face_subset/
# 225 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1004_ITS_ANG_XX_frames_to_cropped_face_subset/
# 226 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1004_ITS_DIS_XX_frames_to_cropped_face_subset/
# 227 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1004_ITS_FEA_XX_frames_to_cropped_face_subset/
# 228 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1004_ITS_SAD_XX_frames_to_cropped_face_subset/
# 229 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1004_IWL_ANG_XX_frames_to_cropped_face_subset/
# 230 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1004_IWL_DIS_XX_frames_to_cropped_face_subset/
# 231 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1004_IWL_FEA_XX_frames_to_cropped_face_subset/
# 232 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1004_IWL_SAD_XX_frames_to_cropped_face_subset/
# 233 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1004_IWW_ANG_XX_frames_to_cropped_face_subset/
# 234 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1004_IWW_DIS_XX_frames_to_cropped_face_subset/
# 235 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1004_IWW_FEA_XX_frames_to_cropped_face_subset/
# 236 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1004_IWW_SAD_XX_frames_to_cropped_face_subset/
# 237 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1004_MTI_ANG_XX_frames_to_cropped_face_subset/
# ...
# 6072 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1090_TIE_HAP_XX_frames_to_cropped_face_subset/
# 6073 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1090_TIE_NEU_XX_frames_to_cropped_face_subset/
# 6074 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1090_TSI_ANG_XX_frames_to_cropped_face_subset/
# 6075 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1090_TSI_DIS_XX_frames_to_cropped_face_subset/
# 6076 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1090_TSI_FEA_XX_frames_to_cropped_face_subset/
# 6077 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1090_TSI_SAD_XX_frames_to_cropped_face_subset/
# 6078 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1090_WSI_ANG_XX_frames_to_cropped_face_subset/
# 6079 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1090_WSI_DIS_XX_frames_to_cropped_face_subset/
# 6080 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1090_WSI_FEA_XX_frames_to_cropped_face_subset/
# 6081 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1090_WSI_HAP_XX_frames_to_cropped_face_subset/
# 6082 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1090_WSI_NEU_XX_frames_to_cropped_face_subset/
# 6083 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1090_WSI_SAD_XX_frames_to_cropped_face_subset/
# 6084 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_DFA_ANG_XX_frames_to_cropped_face_subset/
# 6085 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_DFA_DIS_XX_frames_to_cropped_face_subset/
# 6086 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_DFA_FEA_XX_frames_to_cropped_face_subset/
# 6087 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_DFA_HAP_XX_frames_to_cropped_face_subset/
# 6088 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_DFA_NEU_XX_frames_to_cropped_face_subset/
# 6089 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_IEO_ANG_HI_frames_to_cropped_face_subset/
# 6090 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_IEO_ANG_LO_frames_to_cropped_face_subset/
# 6091 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_IEO_ANG_MD_frames_to_cropped_face_subset/
# 6092 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_IEO_DIS_HI_frames_to_cropped_face_subset/
# 6093 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_IEO_DIS_LO_frames_to_cropped_face_subset/
# 6094 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_IEO_DIS_MD_frames_to_cropped_face_subset/
# 6095 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_IEO_FEA_HI_frames_to_cropped_face_subset/
# 6096 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_IEO_FEA_LO_frames_to_cropped_face_subset/
# 6097 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_IEO_HAP_HI_frames_to_cropped_face_subset/
# 6098 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_IEO_HAP_LO_frames_to_cropped_face_subset/
# 6099 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_IEO_HAP_MD_frames_to_cropped_face_subset/
# 6100 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_IEO_NEU_XX_frames_to_cropped_face_subset/
# 6101 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_IEO_SAD_HI_frames_to_cropped_face_subset/
# 6102 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_IEO_SAD_LO_frames_to_cropped_face_subset/
# 6103 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_IEO_SAD_MD_frames_to_cropped_face_subset/
# 6104 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_IOM_ANG_XX_frames_to_cropped_face_subset/
# 6105 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_IOM_DIS_XX_frames_to_cropped_face_subset/
# 6106 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_IOM_FEA_XX_frames_to_cropped_face_subset/
# 6107 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_IOM_HAP_XX_frames_to_cropped_face_subset/
# 6108 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_IOM_NEU_XX_frames_to_cropped_face_subset/
# 6109 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_ITH_ANG_XX_frames_to_cropped_face_subset/
# 6110 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_ITH_DIS_XX_frames_to_cropped_face_subset/
# 6111 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_ITH_FEA_XX_frames_to_cropped_face_subset/
# 6112 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_ITH_SAD_XX_frames_to_cropped_face_subset/
# 6113 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_ITS_ANG_XX_frames_to_cropped_face_subset/
# 6114 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_ITS_DIS_XX_frames_to_cropped_face_subset/
# 6115 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_ITS_FEA_XX_frames_to_cropped_face_subset/
# 6116 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_ITS_SAD_XX_frames_to_cropped_face_subset/
# 6117 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_IWL_ANG_XX_frames_to_cropped_face_subset/
# 6118 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_IWL_DIS_XX_frames_to_cropped_face_subset/
# 6119 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_IWL_FEA_XX_frames_to_cropped_face_subset/
# 6120 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_IWL_SAD_XX_frames_to_cropped_face_subset/
# 6121 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_IWW_ANG_XX_frames_to_cropped_face_subset/
# 6122 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_IWW_DIS_XX_frames_to_cropped_face_subset/
# 6123 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_IWW_FEA_XX_frames_to_cropped_face_subset/
# 6124 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_IWW_SAD_XX_frames_to_cropped_face_subset/
# 6125 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_MTI_ANG_XX_frames_to_cropped_face_subset/
# 6126 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_MTI_DIS_XX_frames_to_cropped_face_subset/
# 6127 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_MTI_FEA_XX_frames_to_cropped_face_subset/
# 6128 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_MTI_HAP_XX_frames_to_cropped_face_subset/
# 6129 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_MTI_NEU_XX_frames_to_cropped_face_subset/
# 6130 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_MTI_SAD_XX_frames_to_cropped_face_subset/
# 6131 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_TAI_FEA_XX_frames_to_cropped_face_subset/
# 6132 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_TAI_HAP_XX_frames_to_cropped_face_subset/
# 6133 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_TAI_NEU_XX_frames_to_cropped_face_subset/
# 6134 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_TIE_ANG_XX_frames_to_cropped_face_subset/
# 6135 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_TIE_DIS_XX_frames_to_cropped_face_subset/
# 6136 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_TIE_FEA_XX_frames_to_cropped_face_subset/
# 6137 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_TIE_HAP_XX_frames_to_cropped_face_subset/
# 6138 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_TIE_NEU_XX_frames_to_cropped_face_subset/
# 6139 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_TIE_SAD_XX_frames_to_cropped_face_subset/
# 6140 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_TSI_ANG_XX_frames_to_cropped_face_subset/
# 6141 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_TSI_DIS_XX_frames_to_cropped_face_subset/
# 6142 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_TSI_FEA_XX_frames_to_cropped_face_subset/
# 6143 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_TSI_HAP_XX_frames_to_cropped_face_subset/
# 6144 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_TSI_NEU_XX_frames_to_cropped_face_subset/
# 6145 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_TSI_SAD_XX_frames_to_cropped_face_subset/
# 6146 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_WSI_ANG_XX_frames_to_cropped_face_subset/
# 6147 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_WSI_DIS_XX_frames_to_cropped_face_subset/
# 6148 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_WSI_FEA_XX_frames_to_cropped_face_subset/
# 6149 /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/subset_frames_to_faces_crema_d_sub/1091_WSI_SAD_XX_frames_to_cropped_face_subset/

# %%
save_1290_resnet_extracted_features_crema_d = BASE + CLASS_PATH + DATASET_PATH + 'crema_d/extracted_features_crema_d/save_1290_resnet_extracted_features_crema_d'
save_1290_resnet_extracted_features_crema_d

save_resnet_extracted_features_crema_d = BASE + CLASS_PATH + DATASET_PATH + 'crema_d/extracted_features_crema_d/save_resnet_extracted_features_crema_d'
save_resnet_extracted_features_crema_d
# Out:
# '/Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/extracted_features_crema_d/save_resnet_extracted_features_crema_d'

# %%
# Read list to memory
def read_list(list_of_features):
    # for reading also binary mode is important
    with open(list_of_features, 'rb') as fp:
        n_list = pickle.load(fp)
        return n_list

# %%
# read_resnet_crema_d = read_list(save_1290_resnet_extracted_features_crema_d)
read_resnet_crema_d = read_list(save_resnet_extracted_features_crema_d)

# %%
len(read_resnet_crema_d), read_resnet_crema_d[0][0].shape
# Out:
# (6150, torch.Size([1, 2048, 7, 7]))

# %% [markdown]
# # MSP T

# %%
save_resnet_extracted_features_msp_t = BASE + CLASS_PATH + DATASET_PATH + 'msp_t/extracted_features_resnet_msp_t/save_resnet_extracted_features_msp_t'
save_resnet_extracted_features_msp_t

# %%
msp_t_faces = dataset_paths_copy_msp_t['msp_t']
list_msp_t_faces = list(msp_t_faces)
# list_msp_t_faces

# %%
extracted_features_msp_t = extract_features(list_msp_t_faces, save_resnet_extracted_features_msp_t)

# %%
len(extracted_features_msp_t)

# %%
len(extracted_features_msp_t[0]), len(extracted_features_msp_t[1])

# %%
# extracted_features_msp_t[0][4].shape, extracted_features_msp_t[0][4].shape, extracted_features_msp_t[0][4].shape, extracted_features_msp_t[0][4].shape

# %%
# Read list to memory
def read_list(list_of_features):
    # for reading also binary mode is important
    with open(list_of_features, 'rb') as fp:
        n_list = pickle.load(fp)
        return n_list

# %%
reading = read_list(save_resnet_extracted_features_msp_t)

# %%
len(reading)

# %%
reading[651][0].shape

# %%
reading = read_list(save_vit_extracted_features_msp_t2)

# %%
stop timer
