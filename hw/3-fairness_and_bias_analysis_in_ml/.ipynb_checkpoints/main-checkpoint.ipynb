# %% [markdown]
# # HW 3 Fairness and Bias Analysis in Machine Learning (ML)
# - Can "Run All Cells"

# %% [markdown]
# # Imports + Load Data

# %%
import pandas as pd
import numpy as np
import pingouin as pg
from scipy import stats
import itertools

# %%
BASE = "/Users/brinkley97/Documents/development/"
CLASS_PATH = "classes/csci_535_multimodal_probabilistic_learning/"
FBA_DATASET_PATH = "datasets/"
FBA_csv = BASE + CLASS_PATH + FBA_DATASET_PATH + "data.csv"
# FBA_csv

# %%
def load_data(file):
    original_data = pd.read_csv(file)
    # original_data = pd.DataFrame(file)
    copy_of_data = original_data.copy()
    return copy_of_data

# %%
dataset_copy = load_data(FBA_csv)
dataset_copy
# Out:
#                                     Filename  Image #  Gender  Race  \
# 0         Google_1_Danielle Goble_5_oval.jpg        1       1     1
# 1        Google_1_Phillip Owensby_9_oval.jpg        2       0     1
# 2        Google_1_Douglas Ziegler_3_oval.jpg        3       1     1
# 3          Google_1_Donald Sauls_11_oval.jpg        4       1     2
# 4            Google_1_Eric Harman_5_oval.jpg        5       1     6
# ...                                      ...      ...     ...   ...
# 2217  Google_1_Alison Summerville_3_oval.jpg     2218       0     5
# 2218         Google_1_Douglas Yun_3_oval.jpg     2219       0     3
# 2219       Google_1_Wayne Barrios_9_oval.jpg     2220       1     1
# 2220   Google_1_Jennie Kissinger_15_oval.jpg     2221       0     1
# 2221         Google_1_Eileen Burd_7_oval.jpg     2222       0     1
#
#       Confident  Egotistic  Intelligent  Kind  Responsible  Trustworthy  \
# 0          5.67       3.67         5.60  5.00         5.80         5.33
# ...

# %%
traits_df = dataset_copy.drop(['Filename', 'Image #', 'Gender', 'Race', 'Qualified'], axis=1)
traits_df
# Out:
#       Confident  Egotistic  Intelligent  Kind  Responsible  Trustworthy  \
# 0          5.67       3.67         5.60  5.00         5.80         5.33
# 1          6.53       2.20         6.60  7.00         7.47         6.73
# 2          6.07       3.60         6.47  6.47         6.67         6.40
# 3          4.80       4.60         4.47  3.80         4.27         3.87
# 4          6.67       5.40         6.33  4.87         5.87         4.67
# ...         ...        ...          ...   ...          ...          ...
# 2217       6.40       3.73         6.27  5.53         5.87         6.07
# 2218       5.47       5.73         5.67  4.40         5.67         4.07
# 2219       6.67       4.20         5.60  5.93         5.67         5.53
# 2220       6.27       3.93         6.07  5.93         5.60         6.60
# 2221       5.86       4.29         5.64  6.14         5.71         6.29
#
#       Aggressive  Caring  Emotional  Friendly  Sociable
# ...

# %%
traits = traits_df.columns
traits
# Out:
# Index(['Confident', 'Egotistic', 'Intelligent', 'Kind', 'Responsible',
#        'Trustworthy', 'Aggressive', 'Caring', 'Emotional', 'Friendly',
#        'Sociable'],
#       dtype='object')

# %% [markdown]
# # TODOs
#
# 1. Analysis of Variance (ANOVA)
# 2. T-Test
# 3. Rank the top 5 most significant biases you have found (from either race or gender)
# 4. Plot the histograms for the most significant biases

# %% [markdown]
# ## 1. Analysis of Variance (ANOVA)
#
# - To compare 11 traits across 7 races
# - IV: race = [black, white, east asian, south asian, hispanic, middle eastern, other]
# - DV: psychological traits = [confident, egotistic, intelligent, kind, responsible, trustworthy, aggressive, caring, emotional, friendly, sociable]
# - Outcome: p-value for each trait that'll represent the bias...

# %%
race_series = dataset_copy.loc[0:, 'Race']
# race_series

# %%
race_and_traits_df = pd.concat([race_series, traits_df], axis=1)
race_and_traits_df
# Out:
#       Race  Confident  Egotistic  Intelligent  Kind  Responsible  Trustworthy  \
# 0        1       5.67       3.67         5.60  5.00         5.80         5.33
# 1        1       6.53       2.20         6.60  7.00         7.47         6.73
# 2        1       6.07       3.60         6.47  6.47         6.67         6.40
# 3        2       4.80       4.60         4.47  3.80         4.27         3.87
# 4        6       6.67       5.40         6.33  4.87         5.87         4.67
# ...    ...        ...        ...          ...   ...          ...          ...
# 2217     5       6.40       3.73         6.27  5.53         5.87         6.07
# 2218     3       5.47       5.73         5.67  4.40         5.67         4.07
# 2219     1       6.67       4.20         5.60  5.93         5.67         5.53
# 2220     1       6.27       3.93         6.07  5.93         5.60         6.60
# 2221     1       5.86       4.29         5.64  6.14         5.71         6.29
#
# ...

# %%
# mean_of_traits_on_race = race_and_traits_df.mean()
# mean_of_traits_on_race

# %%
def race_trait_anova(df):
    """
    df -- pd DataFrame
    """
    
    store_aov = []
    store_trait = []
    traits = traits_df.columns

    for trait in range(len(traits)):
        specific_trait = traits[trait]
#         print(specific_trait)
        store_trait.append(specific_trait)
        aov = pg.anova(dv=specific_trait, between='Race', data=race_and_traits_df, detailed=True)
#         print(aov)
        store_aov.append(aov)
#         print()
        
    return store_trait, store_aov

# %%
# aov_p_values
aov_traits, aov_for_race_and_trait = race_trait_anova(race_and_traits_df)

# %%
get_p_value = []
for aov_trait_idx in range(len(aov_traits)):
#     print(aov_traits[aov_trait_idx])
    get_p_value.append(aov_for_race_and_trait[aov_trait_idx]['p-unc'][0])

# %%
# aov_traits, get_p_value

# %%
significant_race_traits = []
significant_race_p_values = []

for p_value_idx in range(len(get_p_value)):
#     print(p_value)
    p_value = get_p_value[p_value_idx]
    
    if p_value < 0.01:
#         print(aov_traits[p_value_idx], p_value, '**')
        significant_race_traits.append(aov_traits[p_value_idx])
        significant_race_p_values.append(p_value)
    elif p_value < 0.05:
        pass
#         print(aov_traits[p_value_idx], p_value, '*')
    else:
        pass
#         print(aov_traits[p_value_idx], p_value)

# %%
store_significant_race_traits_with_value = {}
for significant_race_traits_idx in range(len(significant_race_traits)):
    sig_race_trait = 'race_' + significant_race_traits[significant_race_traits_idx]
    store_significant_race_traits_with_value[sig_race_trait] = significant_race_p_values[significant_race_traits_idx]

# %%
store_significant_race_traits_with_value
# Out:
# {'race_Egotistic': 6.035057598195504e-06,
#  'race_Intelligent': 2.1759623149449816e-15,
#  'race_Kind': 0.0002207978957469547,
#  'race_Responsible': 5.968319413679661e-11,
#  'race_Trustworthy': 2.914603741825571e-06,
#  'race_Aggressive': 1.5048230206864964e-10,
#  'race_Caring': 0.0006341517581777635,
#  'race_Friendly': 0.00014411466842194291}

# %%
def mean_median_for_each_race(df):
    """
    """

    all_means = []
    all_medians = []
    race_trait = []
    
    race_numbers = df.loc[0:, 'Race'].unique()
    race_numbers = np.sort(race_numbers)
    
    for race_number in race_numbers:
        
        specific_race = (df['Race'] == race_number)
        specific_race_df = df.loc[specific_race]
        # print(specific_race_df)
        race_trait.append(specific_race_df)
        
        specific_race_mean = specific_race_df.mean()
        all_means.append(specific_race_mean)
        
        specific_race_median = specific_race_df.median()
        all_medians.append(specific_race_median)
        

    return all_means, all_medians, race_trait

# %%
# race_numbers = dataset_copy.loc[0:, 'Race'].unique()
# race_numbers = np.sort(race_numbers)
# race_numbers

# %%
all_race_means, all_race_medians, all_race_trait = mean_median_for_each_race(race_and_traits_df)

# %% [markdown]
# ## Mean

# %%
race_traits_columns = list(race_and_traits_df.columns)
race_mean_df = pd.DataFrame(columns=race_traits_columns)
# race_mean_df

# %%
race_mean_df.append(all_race_means, ignore_index=True)
# Out:
# /var/folders/fz/zn5r8vq12nv5p23dtlr15sk40000gn/T/ipykernel_29810/2412792144.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   race_mean_df.append(all_race_means, ignore_index=True)
#    Race  Confident  Egotistic  Intelligent      Kind  Responsible  \
# 0   0.0   6.600000   3.530000     5.930000  6.665000     6.630000
# 1   1.0   5.925109   4.057195     5.863676  5.715496     5.905479
# 2   2.0   5.967909   4.322545     5.528636  5.404500     5.514227
# 3   3.0   5.836190   3.604444     6.317937  5.857302     6.146032
# 4   4.0   5.612000   4.006000     6.088000  5.540000     5.948000
# 5   5.0   5.742222   4.237917     5.558333  5.356389     5.510139
# 6   6.0   5.939167   4.092917     6.049583  5.619167     5.849167
#
#    Trustworthy  Aggressive    Caring  Emotional  Friendly  Sociable
# 0     6.565000    4.365000  5.700000   5.035000  6.200000  6.000000
# ...

# %% [markdown]
# ## Median

# %%
race_median_df = pd.DataFrame(columns=race_traits_columns)
# race_median_df

# %%
race_median_df.append(all_race_medians)
# Out:
# /var/folders/fz/zn5r8vq12nv5p23dtlr15sk40000gn/T/ipykernel_29810/2528369225.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   race_median_df.append(all_race_medians)
#    Race  Confident  Egotistic  Intelligent   Kind  Responsible  Trustworthy  \
# 0   0.0      6.600      3.530         5.93  6.665         6.63        6.565
# 1   1.0      6.030      4.000         6.00  5.930         6.07        5.800
# 2   2.0      6.130      4.200         5.70  5.835         5.80        5.670
# 3   3.0      5.870      3.330         6.47  6.190         6.27        6.000
# 4   4.0      5.790      3.790         5.93  5.790         5.93        6.000
# 5   5.0      5.835      4.135         5.63  5.465         5.87        5.795
# 6   6.0      6.035      4.100         5.87  5.530         5.90        5.565
#
#    Aggressive  Caring  Emotional  Friendly  Sociable
# 0       4.365   5.700      5.035     6.200      6.00
# ...

# %% [markdown]
# ## 2. T-Test
#
# - To compare 11 traits across 2 genders
# - IV: gender [male, female]
# - DV: psychological traits = [confident, egotistic, intelligent, kind, responsible, trustworthy, aggressive, caring, emotional, friendly, sociable]
# - Outcome: p-value for each trait that'll represent the bias...

# %%
gender_series = dataset_copy.loc[0:, 'Gender']
# gender_series

# %%
gender_and_traits_df = pd.concat([gender_series, traits_df], axis=1)
gender_and_traits_df
# Out:
#       Gender  Confident  Egotistic  Intelligent  Kind  Responsible  \
# 0          1       5.67       3.67         5.60  5.00         5.80
# 1          0       6.53       2.20         6.60  7.00         7.47
# 2          1       6.07       3.60         6.47  6.47         6.67
# 3          1       4.80       4.60         4.47  3.80         4.27
# 4          1       6.67       5.40         6.33  4.87         5.87
# ...      ...        ...        ...          ...   ...          ...
# 2217       0       6.40       3.73         6.27  5.53         5.87
# 2218       0       5.47       5.73         5.67  4.40         5.67
# 2219       1       6.67       4.20         5.60  5.93         5.67
# 2220       0       6.27       3.93         6.07  5.93         5.60
# 2221       0       5.86       4.29         5.64  6.14         5.71
#
#       Trustworthy  Aggressive  Caring  Emotional  Friendly  Sociable
# 0            5.33        4.80    4.67       3.67      4.33      4.67
# ...

# %%
filt_gender_0 = (gender_and_traits_df['Gender'] == 0)
# filt_gender_0

# %%
# filt_race = (df['Race'] == race_number)
female_df = gender_and_traits_df.loc[filt_gender_0]
female_df
# Out:
#       Gender  Confident  Egotistic  Intelligent  Kind  Responsible  \
# 1          0       6.53       2.20         6.60  7.00         7.47
# 5          0       6.50       2.36         6.00  6.64         6.36
# 18         0       6.87       3.40         6.53  6.20         6.40
# 22         0       7.13       3.20         6.27  6.73         6.53
# 23         0       6.20       3.87         5.73  6.20         5.73
# ...      ...        ...        ...          ...   ...          ...
# 2215       0       5.87       4.47         5.67  5.67         5.80
# 2217       0       6.40       3.73         6.27  5.53         5.87
# 2218       0       5.47       5.73         5.67  4.40         5.67
# 2220       0       6.27       3.93         6.07  5.93         5.60
# 2221       0       5.86       4.29         5.64  6.14         5.71
#
#       Trustworthy  Aggressive  Caring  Emotional  Friendly  Sociable
# 1            6.73        3.13    6.93       5.80      6.73      6.60
# ...

# %%
filt_gender_1 = (gender_and_traits_df['Gender'] == 1)
# filt_gender_1

# %%
male_df = gender_and_traits_df.loc[filt_gender_1]
male_df
# Out:
#       Gender  Confident  Egotistic  Intelligent  Kind  Responsible  \
# 0          1       5.67       3.67         5.60  5.00         5.80
# 2          1       6.07       3.60         6.47  6.47         6.67
# 3          1       4.80       4.60         4.47  3.80         4.27
# 4          1       6.67       5.40         6.33  4.87         5.87
# 6          1       6.20       2.27         5.13  6.60         5.87
# ...      ...        ...        ...          ...   ...          ...
# 2212       1       4.40       5.47         3.87  4.00         3.20
# 2213       1       5.79       3.57         6.79  5.79         6.50
# 2214       1       5.21       4.86         5.43  4.07         4.57
# 2216       1       5.20       3.33         6.27  6.60         5.67
# 2219       1       6.67       4.20         5.60  5.93         5.67
#
#       Trustworthy  Aggressive  Caring  Emotional  Friendly  Sociable
# 0            5.33        4.80    4.67       3.67      4.33      4.67
# ...

# %%
# list(female_df.loc[0:, 'Confident'])

# %%
# list(male_df.loc[0:, 'Confident'])

# %%
def female_male_ttest(f_df, m_df):
    """
    """
    
    significant_traits = []
    significant_p_values = []
    all_gender_p_values = []
    store_p_values_in_df = pd.DataFrame()
    for trait in range(len(traits)):
        specific_trait = traits[trait]
        # print(specific_trait)
        
        # print(f_df[specific_trait], m_df[specific_trait])
        stat_result, p_result = stats.ttest_ind(f_df.loc[0:, specific_trait], m_df.loc[0:, specific_trait])
        # print(stat_result)
        # print(p_result)
        
        if p_result < 0.01:
            # print(specific_trait, p_result, '**')
            significant_traits.append(specific_trait)
            significant_p_values.append(p_result)
            all_gender_p_values.append(p_result)
        elif p_result < 0.05:
            # print(specific_trait, p_result, '*')
            all_gender_p_values.append(p_result)
        else:
            # print(specific_trait, p_result)
            all_gender_p_values.append(p_result)

    return significant_traits, significant_p_values, all_gender_p_values

# %%
significant_gender_traits, significant_gender_p_values, all_gender_trait_p_values = female_male_ttest(female_df, male_df)
# significant_gender_traits, significant_gender_p_values

# %%
store_significant_gender_traits_with_value = {}
for significant_gender_traits_idx in range(len(significant_gender_traits)):
    trait = 'gender_' + significant_gender_traits[significant_gender_traits_idx]
    store_significant_gender_traits_with_value[trait] = significant_gender_p_values[significant_gender_traits_idx]

# %%
store_significant_gender_traits_with_value
# Out:
# {'gender_Confident': 0.0002490671279198179,
#  'gender_Egotistic': 5.724535735483598e-103,
#  'gender_Intelligent': 6.617541566954897e-10,
#  'gender_Kind': 3.6772754632964984e-84,
#  'gender_Responsible': 5.314276336798082e-34,
#  'gender_Trustworthy': 5.706506511591532e-73,
#  'gender_Aggressive': 6.29311355462135e-101,
#  'gender_Caring': 6.745136923994714e-105,
#  'gender_Emotional': 1.029377924430242e-164,
#  'gender_Friendly': 3.7108186188491455e-64,
#  'gender_Sociable': 3.1946748840509533e-62}

# %% [markdown]
# ## 3. Rank the top 5 most significant biases

# %%
sig_race_traits = sorted(store_significant_race_traits_with_value.items(), key=lambda x:x[1])
converted_sig_race_traits_dict = dict(sig_race_traits)
print(converted_sig_race_traits_dict)
# Out:
# {'race_Intelligent': 2.1759623149449816e-15, 'race_Responsible': 5.968319413679661e-11, 'race_Aggressive': 1.5048230206864964e-10, 'race_Trustworthy': 2.914603741825571e-06, 'race_Egotistic': 6.035057598195504e-06, 'race_Friendly': 0.00014411466842194291, 'race_Kind': 0.0002207978957469547, 'race_Caring': 0.0006341517581777635}

# %%
sig_gender_traits = sorted(store_significant_gender_traits_with_value.items(), key=lambda x:x[1])
converted_sig_gender_traits_dict = dict(sig_gender_traits)
print(converted_sig_gender_traits_dict)
# Out:
# {'gender_Emotional': 1.029377924430242e-164, 'gender_Caring': 6.745136923994714e-105, 'gender_Egotistic': 5.724535735483598e-103, 'gender_Aggressive': 6.29311355462135e-101, 'gender_Kind': 3.6772754632964984e-84, 'gender_Trustworthy': 5.706506511591532e-73, 'gender_Friendly': 3.7108186188491455e-64, 'gender_Sociable': 3.1946748840509533e-62, 'gender_Responsible': 5.314276336798082e-34, 'gender_Intelligent': 6.617541566954897e-10, 'gender_Confident': 0.0002490671279198179}

# %%
# converted_sig_gender_traits_dict.update()

# %%
# all_significant_biases = converted_sig_gender_traits_dict | converted_sig_race_traits_dict

# %%
# all_significant_biases

# %%
# significant_race_gender_traits = sorted(all_significant_biases.items(), key=lambda x:x[1])
# significant_race_gender_traits_dict = dict(significant_race_gender_traits)
# print(significant_race_gender_traits_dict)

# %%
top_five_race_biases = dict(itertools.islice(converted_sig_race_traits_dict.items(), 5))
top_five_race_biases
# Out:
# {'race_Intelligent': 2.1759623149449816e-15,
#  'race_Responsible': 5.968319413679661e-11,
#  'race_Aggressive': 1.5048230206864964e-10,
#  'race_Trustworthy': 2.914603741825571e-06,
#  'race_Egotistic': 6.035057598195504e-06}

# %%
top_five_gender_biases = dict(itertools.islice(converted_sig_gender_traits_dict.items(), 5))
top_five_gender_biases
# Out:
# {'gender_Emotional': 1.029377924430242e-164,
#  'gender_Caring': 6.745136923994714e-105,
#  'gender_Egotistic': 5.724535735483598e-103,
#  'gender_Aggressive': 6.29311355462135e-101,
#  'gender_Kind': 3.6772754632964984e-84}

# %% [markdown]
# ## 4. Plot the histograms for the most significant biases
# - I thought histograms show the most occurring observation. Not sure how histograms work with significance due to the variety of p-values we can obtain from anova and t-test
# - http://varianceexplained.org/statistics/interpreting-pvalue-histogram/

# %%
most_significiant_race_biases_df = pd.DataFrame.from_dict(top_five_race_biases, orient='index')
most_significiant_race_biases_df
# Out:
#                              0
# race_Intelligent  2.175962e-15
# race_Responsible  5.968319e-11
# race_Aggressive   1.504823e-10
# race_Trustworthy  2.914604e-06
# race_Egotistic    6.035058e-06

# %%
most_significiant_race_biases_df = most_significiant_race_biases_df.T
most_significiant_race_biases_df
# Out:
#    race_Intelligent  race_Responsible  race_Aggressive  race_Trustworthy  \
# 0      2.175962e-15      5.968319e-11     1.504823e-10          0.000003
#
#    race_Egotistic
# 0        0.000006

# %%
most_significiant_race_biases_df.plot.hist()
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
most_significiant_gender_biases_df = pd.DataFrame.from_dict(top_five_gender_biases, orient='index')
most_significiant_gender_biases_df
# Out:
#                                0
# gender_Emotional   1.029378e-164
# gender_Caring      6.745137e-105
# gender_Egotistic   5.724536e-103
# gender_Aggressive  6.293114e-101
# gender_Kind         3.677275e-84

# %%
most_significiant_gender_biases_df = most_significiant_gender_biases_df.T
most_significiant_gender_biases_df
# Out:
#    gender_Emotional  gender_Caring  gender_Egotistic  gender_Aggressive  \
# 0     1.029378e-164  6.745137e-105     5.724536e-103      6.293114e-101
#
#     gender_Kind
# 0  3.677275e-84

# %%
most_significiant_gender_biases_df.plot.hist()
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
aov_p_values = get_p_value
tt_p_values = all_gender_trait_p_values

# %% [markdown]
# ---

# %%
aov_hist_plot = pd.DataFrame(aov_p_values, columns=["Gender x Trait"])
aov_hist_plot.plot.hist()
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %% [markdown]
# - Chart above
# `This plot shows that 8 p-values around/under 0.05. One occurance for both gender_Aggresive and gender_Kind.`

# %% [markdown]
# ---

# %%
aov_hist_plot = pd.DataFrame(tt_p_values, columns=["Race x Trait"])
aov_hist_plot.plot.hist()
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %% [markdown]
# `This plot shows that 10 p-values around/under 0.00005 with a single outlier near 0.00025 for Gender x Trait`

# %% [markdown]
# ## 5. Identify any possible adversities toward certain groups

# %%
selection_rate_df = dataset_copy.loc[0:, ['Race', 'Gender', 'Qualified']]

# %%
not_eligible = (selection_rate_df['Qualified'] == 0)
not_eligible_df = selection_rate_df[not_eligible]
not_eligible_df
# Out:
#       Race  Gender  Qualified
# 0        1       1          0
# 2        1       1          0
# 3        2       1          0
# 5        1       0          0
# 6        1       1          0
# ...    ...     ...        ...
# 2215     1       0          0
# 2216     1       1          0
# 2217     5       0          0
# 2218     3       0          0
# 2221     1       0          0
#
# [1844 rows x 3 columns]

# %%
eligible = (selection_rate_df['Qualified'] == 1)
eligible_df = selection_rate_df[eligible]
eligible_df
# Out:
#       Race  Gender  Qualified
# 1        1       0          1
# 4        6       1          1
# 8        2       1          1
# 12       1       1          1
# 35       1       1          1
# ...    ...     ...        ...
# 2182     1       0          1
# 2196     1       1          1
# 2201     2       1          1
# 2219     1       1          1
# 2220     1       0          1
#
# [378 rows x 3 columns]

# %%
not_eligible_to_all_ratio = len(not_eligible_df) / len(selection_rate_df)
not_eligible_to_all_ratio
# Out:
# 0.8298829882988299

# %%
eligible_to_all_ratio = len(eligible_df) / len(selection_rate_df)
eligible_to_all_ratio
# Out:
# 0.1701170117011701

# %% [markdown]
# ---

# %%
# set to 1 so we can count the total
not_eligible_df.loc[0:, 'Qualified'] = 1
not_eligible_df
not_eligible_df.groupby('Race').agg({'Qualified': np.sum})
# Out:
# /var/folders/fz/zn5r8vq12nv5p23dtlr15sk40000gn/T/ipykernel_29810/401782602.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   not_eligible_df.loc[0:, 'Qualified'] = 1
#       Qualified
# Race
# 0             2
# 1          1500
# 2           193
# 3            52
# 4             5
# 5            70
# 6            22

# %%
1500 * (4/5)
# Out:
# 1200.0

# %% [markdown]
# - Refers to Race (6) x Qualified (0) table above
# - `The highest group is race 1. 4/5 of 1500 = 1200. Groups 0, 2 - 6 are part the four-fifth rule as they lie less than 1200.`

# %% [markdown]
# ---

# %%
selection_rate_df.groupby('Race').agg({'Qualified': np.sum})
# Out:
#       Qualified
# Race
# 0             0
# 1           336
# 2            27
# 3            11
# 4             0
# 5             2
# 6             2

# %%
336 * (4/5)
# Out:
# 268.8

# %% [markdown]
# - Refers to Race (6) x Qualified (1) table above
# - `The highest group is gender 0. 4/5 of 1004 = 265. Gender 1, is part the four-fifth rule as that gender lie less than 265.`

# %% [markdown]
# ---

# %%
selection_rate_df.groupby('Qualified').agg({'Gender': np.sum})
# Out:
#            Gender
# Qualified
# 0            1004
# 1             265

# %%
1004 * (4/5)
# Out:
# 803.2

# %% [markdown]
# - Refers to Qualified (2) x Race(2) table above
# - `The highest group is gender 0. 4/5 of 1004 = 265. Gender 1, is part the four-fifth rule as that gender lie less than 265.`

# %% [markdown]
# ## 6. What could be other contributing factors to bias in ML systems, aside from human labeler bias?
#
# - Not having experts in the loop, unconscious bias of developers of ML developers, lack of proper dataset or noisy data collected which could be difficult to clean, train and test. Not enough data overall. Think with certain rare diseases. Of course we don’t want people to have any diseases. Those rare diseases are more difficult even for medical personnel to determine proper procedure and not enough data for ML develops.

# %% [markdown]
# ## 7. How can you mitigate such biases in machine learning? Please explain
#
# - See my previous answer along with passing the proper legislation to mitigate bias. Provide explainability and interpretability for when bias occurs and what triggers that bias (when model is deployed)
# - An Ethical Framework for Guiding the Development of Affectively-Aware Artificial Intelligence by Ong, et al.
