# %%
import os
import os.path
import shutil

from pathlib import Path

# %%
BASE = '/Users/brinkley97/Documents/development/'
CLASS_PATH = 'classes/csci_535_multimodal_probabilistic_learning/'
DATASET_PATH = 'datasets/'

# %%
def copy_face_frame_to_new_folder(path_to_faces_in_specific_folder, update_copy_location):
            
    files = os.listdir(path_to_faces_in_specific_folder)
    
    for file in files:
        shutil.copy2(os.path.join(path_to_faces_in_specific_folder, file), update_copy_location)
        # print("Success")

# %%
def face_to_specific_emotion_folder(path_to_faces, path_to_copy_specific_face):
    """
    
    Parameters:
    path_to_faces -- str (of where to get the frames from)
    path_to_copy_specific_face -- str (of where to copy frames to)
    
    Function calls: 
    extract_features
    
    """
    
    face_folder_files = os.listdir(path_to_faces)
        
    for face_folder_file_idx in range(len(face_folder_files)):
        specific_face_folder = face_folder_files[face_folder_file_idx]
        split_specific_face_folder = specific_face_folder.split('_')
        print(face_folder_file_idx, specific_face_folder)
        
        path_to_faces_in_specific_folder = path_to_faces + specific_face_folder + "/"
        
        if 'ANG' in split_specific_face_folder:
            update_copy_location = path_to_copy_specific_face + 'ang_crema_d/'
            copy_face_frame_to_new_folder(path_to_faces_in_specific_folder, update_copy_location)
            print("Success")
        
        if 'DIS' in split_specific_face_folder:
            update_copy_location = path_to_copy_specific_face + 'dis_crema_d/'
            copy_face_frame_to_new_folder(path_to_faces_in_specific_folder, update_copy_location)
            print("Success")

        if 'FEA' in split_specific_face_folder:
            update_copy_location = path_to_copy_specific_face + 'fea_crema_d/'
            copy_face_frame_to_new_folder(path_to_faces_in_specific_folder, update_copy_location)
            print("Success")
            
        if 'HAP' in split_specific_face_folder:
            update_copy_location = path_to_copy_specific_face + 'hap_crema_d/'
            copy_face_frame_to_new_folder(path_to_faces_in_specific_folder, update_copy_location)
            print("Success")
            
        if 'NEU' in split_specific_face_folder:
            update_copy_location = path_to_copy_specific_face + 'neu_crema_d/'
            copy_face_frame_to_new_folder(path_to_faces_in_specific_folder, update_copy_location)
            print("Success")
        
        if 'SAD' in split_specific_face_folder:
            update_copy_location = path_to_copy_specific_face + 'sad_crema_d/'
            copy_face_frame_to_new_folder(path_to_faces_in_specific_folder, update_copy_location)
            print("Success")
        print()

# %%
CREMA_D_FRAMES_TO_FACE_PATH = BASE + CLASS_PATH + DATASET_PATH + 'project/crema_d/frames_to_faces_crema_d/'
CREMA_D_FRAMES_TO_FACE_PATH
# Out:
# '/Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/frames_to_faces_crema_d/'

# %%
COPY_CREMA_D_FACE_TO_EMOTION_FOLDER_PATH = BASE + CLASS_PATH + DATASET_PATH + 'project/crema_d/faces_to_specific_emotion_folder_crema_d/'
COPY_CREMA_D_FACE_TO_EMOTION_FOLDER_PATH
# Out:
# '/Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/project/crema_d/faces_to_specific_emotion_folder_crema_d/'

# %%
face_to_specific_emotion_folder(CREMA_D_FRAMES_TO_FACE_PATH, COPY_CREMA_D_FACE_TO_EMOTION_FOLDER_PATH)
# Out:
# 0 1071_ITS_SAD_XX_frames_to_cropped_face
# Success
#
#
DFA_FEA_XX_frames_to_cropped_face
# Success
#
# 840 1089_TSI_FEA_XX_frames_to_cropped_face
# Success
#
# 841 1060_WSI_ANG_XX_frames_to_cropped_face
# Success
#
# 842 1045_WSI_DIS_XX_frames_to_cropped_face
# Success
#
# 843 1026_ITS_FEA_XX_frames_to_cropped_face
# Success
#
# 844 1071_IWW_SAD_XX_frames_to_cropped_face
# Success
#
# 845 1063_IEO_FEA_HI_frames_to_cropped_face
# Success
#
# 846 1014_IEO_ANG_MD_frames_to_cropped_face
# Success
#
# 847 1031_IEO_DIS_MD_frames_to_cropped_face
# Success
#
# 848 1060_IWL_SAD_XX_frames_to_cropped_face
# Success
#
# 849 1090_IEO_DIS_MD_frames_to_cropped_face
# Success
#
# 850 1091_IEO_FEA_MD_frames_to_cropped_face
# Success
#
# 851 1001_IEO_DIS_LO_frames_to_cropped_face
# Success
#
# 852 1063_MTI_HAP_XX_frames_to_cropped_face
# Success
#
# 853 1024_IEO_ANG_LO_frames_to_cropped_face
# Success
#
# 854 1011_IOM_NEU_XX_frames_to_cropped_face
# Success
#
# 855 1079_MTI_ANG_XX_frames_to_cropped_face
# Success
#
# 856 1052_TAI_SAD_XX_frames_to_cropped_face
# Success
#
# 857 1030_IEO_FEA_MD_frames_to_cropped_face
# Success
#
# 858 1047_IEO_ANG_HI_frames_to_cropped_face
# Success
#
# 859 1085_IEO_ANG_LO_frames_to_cropped_face
# Success
#
# 860 1062_IEO_DIS_HI_frames_to_cropped_face
# Success
#
# 861 1034_IOM_HAP_XX_frames_to_cropped_face
# Success
#
# 862 1046_MTI_NEU_XX_frames_to_cropped_face
# Success
#
# 863 1044_WSI_FEA_XX_frames_to_cropped_face
# Success
#
# 864 1027_ITS_DIS_XX_frames_to_cropped_face
# Success
#
# 865 1002_ITS_ANG_XX_frames_to_cropped_face
# Success
#
# 866 1056_DFA_HAP_XX_frames_to_cropped_face
# Success
#
# 867 1088_TSI_DIS_XX_frames_to_cropped_face
# Success
#
# 868 1018_ITS_HAP_XX_frames_to_cropped_face
# Success
#
# 869 1033_TSI_NEU_XX_frames_to_cropped_face
# Success
#
# 870 1033_TIE_SAD_XX_frames_to_cropped_face
# Success
#
# 871 1069_DFA_DIS_XX_frames_to_cropped_face
# Success
#
# 872 1013_ITH_ANG_XX_frames_to_cropped_face
# Success
#
# 873 1016_TSI_HAP_XX_frames_to_cropped_face
# Success
#
# 874 1036_ITH_DIS_XX_frames_to_cropped_face
# Success
#
# 875 1073_DFA_NEU_XX_frames_to_cropped_face
# Success
#
# 876 1086_ITS_DIS_XX_frames_to_cropped_face
# Success
#
# 877 1009_ITH_HAP_XX_frames_to_cropped_face
# Success
#
# 878 1029_TSI_DIS_XX_frames_to_cropped_face
# Success
#
# 879 1030_TAI_SAD_XX_frames_to_cropped_face
# Success
#
# 880 1069_IOM_DIS_XX_frames_to_cropped_face
# Success
#
# 881 1024_MTI_NEU_XX_frames_to_cropped_face
# Success
#
# 882 1056_IOM_HAP_XX_frames_to_cropped_face
# Success
#
# 883 1052_IEO_FEA_MD_frames_to_cropped_face
# Success
#
# 884 1025_IEO_ANG_HI_frames_to_cropped_face
# Success
#
# 885 1073_IOM_NEU_XX_frames_to_cropped_face
# Success
#
# 886 1085_MTI_NEU_XX_frames_to_cropped_face
# Success
#
# 887 1046_IEO_ANG_LO_frames_to_cropped_face
# Success
#
# 888 1063_IEO_DIS_LO_frames_to_cropped_face
# Success
#
# 889 1001_MTI_HAP_XX_frames_to_cropped_face
# Success
#
# 890 1084_IEO_ANG_HI_frames_to_cropped_face
# Success
#
# 891 1091_TAI_SAD_XX_frames_to_cropped_face
# Success
#
# 892 1074_TSI_HAP_XX_frames_to_cropped_face
# Success
#
# 893 1054_ITH_DIS_XX_frames_to_cropped_face
# Success
#
# 894 1071_ITH_ANG_XX_frames_to_cropped_face
# Success
#
# 895 1087_WSI_FEA_XX_frames_to_cropped_face
# Success
#
# 896 1011_DFA_NEU_XX_frames_to_cropped_face
# Success
#
# 897 1034_DFA_HAP_XX_frames_to_cropped_face
# Success
#
# 898 1060_ITS_ANG_XX_frames_to_cropped_face
# Success
#
# 899 1045_ITS_DIS_XX_frames_to_cropped_face
# Success
#
# 900 1026_WSI_FEA_XX_frames_to_cropped_face
# Success
#
# 901 1051_TIE_SAD_XX_frames_to_cropped_face
# Success
#
# 902 1051_TSI_NEU_XX_frames_to_cropped_face
# Success
#
# 903 1089_IEO_SAD_HI_frames_to_cropped_face
# Success
#
# 904 1002_TAI_NEU_XX_frames_to_cropped_face
# Success
#
# 905 1086_TAI_HAP_XX_frames_to_cropped_face
# Success
#
# 906 1016_MTI_SAD_XX_frames_to_cropped_face
# Success
#
# 907 1041_IOM_SAD_XX_frames_to_cropped_face
# Success
#
# 908 1018_TAI_DIS_XX_frames_to_cropped_face
# Success
#
# 909 1028_IEO_SAD_HI_frames_to_cropped_face
# Success
#
# 910 1027_TAI_HAP_XX_frames_to_cropped_face
# Success
#
# 911 1046_TIE_HAP_XX_frames_to_cropped_face
# Success
#
# 912 1079_TIE_DIS_XX_frames_to_cropped_face
# Success
#
# 913 1023_DFA_SAD_XX_frames_to_cropped_face
# Success
#
# 914 1082_DFA_SAD_XX_frames_to_cropped_face
# Success
#
# 915 1063_TIE_NEU_XX_frames_to_cropped_face
# Success
#
# 916 1063_TSI_SAD_XX_frames_to_cropped_face
# Success
#
# 917 1023_IOM_SAD_XX_frames_to_cropped_face
# Success
#
# 918 1045_TAI_HAP_XX_frames_to_cropped_face
# Success
#
# 919 1058_IWW_FEA_XX_frames_to_cropped_face
# Success
#
# 920 1088_IEO_SAD_LO_frames_to_cropped_face
# Success
#
# 921 1029_IEO_SAD_LO_frames_to_cropped_face
# Success
#
# 922 1060_TAI_NEU_XX_frames_to_cropped_face
# Success
#
# 923 1074_MTI_SAD_XX_frames_to_cropped_face
# Success
#
# 924 1082_IOM_SAD_XX_frames_to_cropped_face
# Success
#
# ...
# Success
#
# 7142 1015_WSI_SAD_XX_frames_to_cropped_face
# Success
#
# 7143 1061_IEO_SAD_MD_frames_to_cropped_face
# Success
#
# 7144 1021_IWW_DIS_XX_frames_to_cropped_face
# Success
#
# 7145 1004_IWW_ANG_XX_frames_to_cropped_face
# Success
#
# 7146 1091_IWL_DIS_XX_frames_to_cropped_face
# Success
#
# 7147 1003_TAI_FEA_XX_frames_to_cropped_face
# Success
#
# 7148 1015_IWL_ANG_XX_frames_to_cropped_face
# Success
#
# 7149 1030_IWL_DIS_XX_frames_to_cropped_face
# Success
#
# 7150 1080_IWW_DIS_XX_frames_to_cropped_face
# Success
#
# 7151 1081_IWW_FEA_XX_frames_to_cropped_face
# Success
#
# 7152 1018_TAI_NEU_XX_frames_to_cropped_face
# Success
#
# 7153 1051_IEO_SAD_LO_frames_to_cropped_face
# Success
#
# 7154 1086_TAI_ANG_XX_frames_to_cropped_face
# Success
#
# 7155 1031_IWL_FEA_XX_frames_to_cropped_face
# Success
#
# 7156 1027_TAI_ANG_XX_frames_to_cropped_face
# Success
#
# 7157 1002_TAI_DIS_XX_frames_to_cropped_face
# Success
#
# 7158 1090_IWL_FEA_XX_frames_to_cropped_face
# Success
#
# 7159 1020_IWW_FEA_XX_frames_to_cropped_face
# Success
#
# 7160 1032_IEO_SAD_HI_frames_to_cropped_face
# Success
#
# 7161 1077_ITS_SAD_XX_frames_to_cropped_face
# Success
#
# 7162 1046_TIE_ANG_XX_frames_to_cropped_face
# Success
#
# 7163 1063_TIE_DIS_XX_frames_to_cropped_face
# Success
#
# 7164 1039_DFA_SAD_XX_frames_to_cropped_face
# Success
#
# 7165 1066_ITH_SAD_XX_frames_to_cropped_face
# Success
#
# 7166 1079_TSI_SAD_XX_frames_to_cropped_face
# Success
#
# 7167 1079_TIE_NEU_XX_frames_to_cropped_face
# Success
#
# 7168 1039_IOM_SAD_XX_frames_to_cropped_face
# Success
#
# 7169 1060_TAI_DIS_XX_frames_to_cropped_face
# Success
#
# 7170 1045_TAI_ANG_XX_frames_to_cropped_face
# Success
#
# 7171 1050_IEO_SAD_HI_frames_to_cropped_face
# Success
#
# 7172 1042_IWW_FEA_XX_frames_to_cropped_face
# Success
#
# 7173 1033_IEO_SAD_LO_frames_to_cropped_face
# Success
#
# 7174 1053_IWL_FEA_XX_frames_to_cropped_face
# Success
#
# 7175 1004_ITH_SAD_XX_frames_to_cropped_face
# Success
#
# 7176 1085_TIE_ANG_XX_frames_to_cropped_face
# Success
#
# 7177 1015_ITS_SAD_XX_frames_to_cropped_face
# Success
#
# 7178 1001_TIE_DIS_XX_frames_to_cropped_face
# Success
#
# 7179 1024_TIE_ANG_XX_frames_to_cropped_face
# Success
#
# 7180 1079_MTI_HAP_XX_frames_to_cropped_face
# Success
#
# 7181 1046_MTI_DIS_XX_frames_to_cropped_face
# Success
#
# 7182 1024_IEO_HAP_LO_frames_to_cropped_face
# Success
#
# 7183 1063_MTI_ANG_XX_frames_to_cropped_face
# Success
#
# 7184 1048_TAI_SAD_XX_frames_to_cropped_face
# Success
#
# 7185 1085_IEO_HAP_LO_frames_to_cropped_face
# Success
#
# 7186 1034_IOM_ANG_XX_frames_to_cropped_face
# Success
#
# 7187 1011_IOM_DIS_XX_frames_to_cropped_face
# Success
#
# 7188 1047_IEO_HAP_HI_frames_to_cropped_face
# Success
#
# 7189 1078_IEO_DIS_HI_frames_to_cropped_face
# Success
#
# 7190 1036_ITH_NEU_XX_frames_to_cropped_face
# Success
#
# 7191 1018_ITS_ANG_XX_frames_to_cropped_face
# Success
#
# 7192 1086_ITS_NEU_XX_frames_to_cropped_face
# Success
#
# 7193 1029_TIE_SAD_XX_frames_to_cropped_face
# Success
#
# 7194 1073_DFA_DIS_XX_frames_to_cropped_face
# Success
#
# 7195 1056_DFA_ANG_XX_frames_to_cropped_face
# Success
#
# 7196 1002_ITS_HAP_XX_frames_to_cropped_face
# Success
#
# 7197 1029_TSI_NEU_XX_frames_to_cropped_face
# Success
#
# 7198 1088_TIE_SAD_XX_frames_to_cropped_face
# Success
#
# 7199 1009_ITH_ANG_XX_frames_to_cropped_face
# Success
#
# 7200 1027_ITS_NEU_XX_frames_to_cropped_face
# Success
#
#
IWW_ANG_XX_frames_to_cropped_face
# Success
#
# 7347 1004_IWW_DIS_XX_frames_to_cropped_face
# Success
#
# 7348 1021_IWW_ANG_XX_frames_to_cropped_face
# Success
#
# 7349 1044_IEO_SAD_MD_frames_to_cropped_face
# Success
#
# 7350 1026_TAI_FEA_XX_frames_to_cropped_face
# Success
#
# 7351 1091_IWL_ANG_XX_frames_to_cropped_face
# Success
#
# 7352 1047_TIE_FEA_XX_frames_to_cropped_face
# Success
#
# 7353 1030_WSI_SAD_XX_frames_to_cropped_face
# Success
#
# 7354 1091_WSI_SAD_XX_frames_to_cropped_face
# Success
#
# 7355 1049_IEO_ANG_MD_frames_to_cropped_face
# Success
#
# 7356 1053_IEO_HAP_MD_frames_to_cropped_face
# Success
#
# 7357 1057_IOM_FEA_XX_frames_to_cropped_face
# Success
#
# 7358 1010_IEO_NEU_XX_frames_to_cropped_face
# Success
#
# 7359 1075_TSI_FEA_XX_frames_to_cropped_face
# Success
#
# 7360 1086_WSI_HAP_XX_frames_to_cropped_face
# Success
#
# 7361 1002_WSI_NEU_XX_frames_to_cropped_face
# Success
#
# 7362 1027_WSI_HAP_XX_frames_to_cropped_face
# Success
#
# 7363 1035_DFA_FEA_XX_frames_to_cropped_face
# Success
#
# 7364 1018_WSI_DIS_XX_frames_to_cropped_face
# Success
#
# 7365 1062_MTI_FEA_XX_frames_to_cropped_face
# Success
#
# 7366 1090_IEO_HAP_MD_frames_to_cropped_face
# Success
#
# 7367 1072_IEO_NEU_XX_frames_to_cropped_face
# Success
#
# 7368 1035_IOM_FEA_XX_frames_to_cropped_face
# Success
#
# 7369 1031_IEO_HAP_MD_frames_to_cropped_face
# Success
#
# 7370 1057_DFA_FEA_XX_frames_to_cropped_face
# Success
#
# 7371 1045_WSI_HAP_XX_frames_to_cropped_face
# Success
#
# 7372 1019_ITS_FEA_XX_frames_to_cropped_face
# Success
#
# 7373 1017_TSI_FEA_XX_frames_to_cropped_face
# Success
#
# 7374 1008_ITH_FEA_XX_frames_to_cropped_face
# Success
#
# 7375 1060_WSI_NEU_XX_frames_to_cropped_face
# Success
#
# 7376 1086_ITS_HAP_XX_frames_to_cropped_face
# Success
#
# 7377 1002_ITS_NEU_XX_frames_to_cropped_face
# Success
#
# 7378 1009_ITH_DIS_XX_frames_to_cropped_face
# Success
#
# 7379 1029_TSI_HAP_XX_frames_to_cropped_face
# Success
#
# 7380 1033_TSI_ANG_XX_frames_to_cropped_face
# Success
#
# 7381 1016_TSI_DIS_XX_frames_to_cropped_face
# Success
#
# 7382 1036_ITH_HAP_XX_frames_to_cropped_face
# Success
#
# 7383 1018_ITS_DIS_XX_frames_to_cropped_face
# Success
#
# 7384 1013_ITH_NEU_XX_frames_to_cropped_face
# Success
#
# 7385 1069_DFA_HAP_XX_frames_to_cropped_face
# Success
#
# 7386 1027_ITS_HAP_XX_frames_to_cropped_face
# Success
#
# 7387 1056_DFA_DIS_XX_frames_to_cropped_face
# Success
#
# 7388 1088_TSI_HAP_XX_frames_to_cropped_face
# Success
#
# 7389 1073_DFA_ANG_XX_frames_to_cropped_face
# Success
#
# 7390 1011_IOM_ANG_XX_frames_to_cropped_face
# Success
#
# 7391 1062_IEO_HAP_HI_frames_to_cropped_face
# Success
#
# 7392 1034_IOM_DIS_XX_frames_to_cropped_face
# Success
#
# 7393 1078_IEO_ANG_HI_frames_to_cropped_face
# Success
#
# 7394 1079_MTI_NEU_XX_frames_to_cropped_face
# Success
#
# 7395 1001_IEO_HAP_LO_frames_to_cropped_face
# Success
#
# 7396 1063_MTI_DIS_XX_frames_to_cropped_face
# Success
#
# 7397 1046_MTI_ANG_XX_frames_to_cropped_face
# Success
#
# 7398 1071_ITH_NEU_XX_frames_to_cropped_face
# Success
#
# 7399 1019_WSI_FEA_XX_frames_to_cropped_face
# Success
#
# 7400 1011_DFA_ANG_XX_frames_to_cropped_face
# Success
#
# 7401 1034_DFA_DIS_XX_frames_to_cropped_face
# Success
#
# 7402 1045_ITS_HAP_XX_frames_to_cropped_face
# Success
#
# 7403 1060_ITS_NEU_XX_frames_to_cropped_face
# Success
#
# 7404 1074_TSI_DIS_XX_frames_to_cropped_face
# Success
#
# 7405 1054_ITH_HAP_XX_frames_to_cropped_face
# Success
#
# 7406 1051_TSI_ANG_XX_frames_to_cropped_face
# Success
#
# 7407 1079_IEO_ANG_LO_frames_to_cropped_face
# Success
#
# 7408 1024_MTI_ANG_XX_frames_to_cropped_face
# Success
#
# 7409 1063_IEO_HAP_LO_frames_to_cropped_face
# Success
#
# 7410 1001_MTI_DIS_XX_frames_to_cropped_face
# Success
#
# 7411 1085_MTI_ANG_XX_frames_to_cropped_face
# Success
#
# 7412 1056_IOM_DIS_XX_frames_to_cropped_face
# Success
#
# 7413 1073_IOM_ANG_XX_frames_to_cropped_face
# Success
#
# 7414 1069_IOM_HAP_XX_frames_to_cropped_face
# Success
#
# 7415 1043_ITH_SAD_XX_frames_to_cropped_face
# Success
#
# 7416 1052_ITS_SAD_XX_frames_to_cropped_face
# Success
#
# 7417 1079_TIE_HAP_XX_frames_to_cropped_face
# Success
#
# 7418 1063_TIE_ANG_XX_frames_to_cropped_face
# Success
#
# 7419 1046_TIE_DIS_XX_frames_to_cropped_face
# Success
#
# 7420 1088_MTI_SAD_XX_frames_to_cropped_face
# Success
#
# 7421 1002_TAI_ANG_XX_frames_to_cropped_face
# Success
#
# 7422 1027_TAI_DIS_XX_frames_to_cropped_face
# Success
#
# 7423 1017_IEO_SAD_HI_frames_to_cropped_face
# Success
#
# 7424 1005_IWW_FEA_XX_frames_to_cropped_face
# Success
#
# 7425 1018_TAI_HAP_XX_frames_to_cropped_face
# Success
#
# 7426 1074_IEO_SAD_LO_frames_to_cropped_face
# Success
#
# 7427 1014_IWL_FEA_XX_frames_to_cropped_face
# Success
#
# 7428 1029_MTI_SAD_XX_frames_to_cropped_face
# Success
#
# 7429 1086_TAI_DIS_XX_frames_to_cropped_face
# Success
#
# 7430 1030_ITS_SAD_XX_frames_to_cropped_face
# Success
#
# 7431 1024_TIE_DIS_XX_frames_to_cropped_face
# Success
#
# 7432 1001_TIE_ANG_XX_frames_to_cropped_face
# Success
#
# 7433 1080_ITH_SAD_XX_frames_to_cropped_face
# Success
#
# 7434 1085_TIE_DIS_XX_frames_to_cropped_face
# Success
#
# 7435 1021_ITH_SAD_XX_frames_to_cropped_face
# Success
#
# 7436 1091_ITS_SAD_XX_frames_to_cropped_face
# Success
#
# 7437 1016_IEO_SAD_LO_frames_to_cropped_face
# Success
#
# 7438 1076_IWL_FEA_XX_frames_to_cropped_face
# Success
#
# 7439 1045_TAI_DIS_XX_frames_to_cropped_face
# Success
#
# 7440 1060_TAI_ANG_XX_frames_to_cropped_face
# Success
#
# 7441 1067_IWW_FEA_XX_frames_to_cropped_face
# Success
#
# 7442 1075_IEO_SAD_HI_frames_to_cropped_face
# Success

# %% [markdown]
# # Verify all files copied over

# %%
total_number_in_emotion_folders = []
emotion_folders = ["ang_crema_d", "dis_crema_d", "fea_crema_d", "hap_crema_d", "neu_crema_d", "sad_crema_d"]
for emotion_folder in emotion_folders:
    
    # print(emotion_folder)

    crema_d_with_emotion = COPY_CREMA_D_FACE_TO_EMOTION_FOLDER_PATH + emotion_folder
    # print(crema_d_with_emotion)
    
    faces_in_emotion_folder = os.listdir(crema_d_with_emotion)
    # print(len(faces_in_emotion_folder), crema_d_with_emotion)
    total_number_in_emotion_folders.append(len(faces_in_emotion_folder))
    
    # print(total_number_in_emotion_folders)

# %%
total = sum(total_number_in_emotion_folders)
print(total)
# Out:
# 569251

# %%
faces_with_folders = os.listdir(CREMA_D_FRAMES_TO_FACE_PATH)
len(faces_with_folders)
# Out:
# 7443

# %%
total_number_in_faces_folders = []

for faces_with_folders_idx in range(len(faces_with_folders)):
    
    if faces_with_folders[faces_with_folders_idx] != '.DS_Store':
        
        path_to_specific_emotion_folder = CREMA_D_FRAMES_TO_FACE_PATH + faces_with_folders[faces_with_folders_idx]
        # print(path_to_specific_emotion_folder)
        faces_in_face_folders = os.listdir(path_to_specific_emotion_folder)
        # print(len(faces_in_face_folders))
        total_number_in_faces_folders.append(len(faces_in_face_folders))

# %%
total_number_in_faces_folders
total_faces = sum(total_number_in_faces_folders)
print(total_faces)
# Out:
# 569251
