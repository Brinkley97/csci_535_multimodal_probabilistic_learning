# %% [markdown]
# # HW 3 Fairness and Bias Analysis in Machine Learning
# - Can "Run All Cells"

# %%
import pandas as pd

# %%
BASE = "/Users/brinkley97/Documents/development/"
CLASS_PATH = "classes/csci_535_multimodal_probabilistic_learning/"
FBA_DATASET_PATH = "datasets/"
FBA_csv = BASE + CLASS_PATH + FBA_DATASET_PATH + "data.csv"
FBA_csv
# Out:
# '/Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/data.csv'

# %%
def load_data(file):
    original_data = pd.read_csv(file)
    # original_data = pd.DataFrame(file)
    copy_of_data = original_data.copy()
    return copy_of_data

# %%
dataset_paths_copy = load_data(FBA_csv)
dataset_paths_copy
# Out:
#                                     Filename  Image #  Gender  Race  \
# 0         Google_1_Danielle Goble_5_oval.jpg        1       1     1
# 1        Google_1_Phillip Owensby_9_oval.jpg        2       0     1
# 2        Google_1_Douglas Ziegler_3_oval.jpg        3       1     1
# 3          Google_1_Donald Sauls_11_oval.jpg        4       1     2
# 4            Google_1_Eric Harman_5_oval.jpg        5       1     6
# ...                                      ...      ...     ...   ...
# 2217  Google_1_Alison Summerville_3_oval.jpg     2218       0     5
# 2218         Google_1_Douglas Yun_3_oval.jpg     2219       0     3
# 2219       Google_1_Wayne Barrios_9_oval.jpg     2220       1     1
# 2220   Google_1_Jennie Kissinger_15_oval.jpg     2221       0     1
# 2221         Google_1_Eileen Burd_7_oval.jpg     2222       0     1
#
#       Confident  Egotistic  Intelligent  Kind  Responsible  Trustworthy  \
# 0          5.67       3.67         5.60  5.00         5.80         5.33
# ...

# %%
dataset_paths_copy.loc[0:, 'Race'].unique()
# Out:
# array([1, 2, 6, 5, 3, 4, 0])

# %%
filt_race_0 = (dataset_paths_copy['Race'] == 0)
filt_race_0
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2217    False
# 2218    False
# 2219    False
# 2220    False
# 2221    False
# Name: Race, Length: 2222, dtype: bool

# %%
r0 = dataset_paths_copy.loc[filt_race_0]
r0
# Out:
#                                     Filename  Image #  Gender  Race  \
# 342   Google_1_Clarence Morehouse_8_oval.jpg      343       1     0
# 1637        Google_1_Steven Mahan_1_oval.jpg     1638       1     0
#
#       Confident  Egotistic  Intelligent  Kind  Responsible  Trustworthy  \
# 342        6.67       2.93         6.33  7.13         6.53         6.73
# 1637       6.53       4.13         5.53  6.20         6.73         6.40
#
#       Aggressive  Caring  Emotional  Friendly  Sociable  Qualified
# 342         4.80    5.33       4.67      5.73      5.73          0
# 1637        3.93    6.07       5.40      6.67      6.27          0

# %%
filt_race_1 = (dataset_paths_copy['Race'] == 1)
filt_race_1
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 2217    False
# 2218    False
# 2219     True
# 2220     True
# 2221     True
# Name: Race, Length: 2222, dtype: bool

# %%
r1 = dataset_paths_copy.loc[filt_race_1]
r1
# Out:
#                                    Filename  Image #  Gender  Race  Confident  \
# 0        Google_1_Danielle Goble_5_oval.jpg        1       1     1       5.67
# 1       Google_1_Phillip Owensby_9_oval.jpg        2       0     1       6.53
# 2       Google_1_Douglas Ziegler_3_oval.jpg        3       1     1       6.07
# 5        Google_1_Peter Grigsby_13_oval.jpg        6       0     1       6.50
# 6     Google_1_Nathan Beauregard_3_oval.jpg        7       1     1       6.20
# ...                                     ...      ...     ...   ...        ...
# 2215    Google_1_Kimberly Mccown_5_oval.jpg     2216       0     1       5.87
# 2216  Google_1_Manuel Cleveland_19_oval.jpg     2217       1     1       5.20
# 2219      Google_1_Wayne Barrios_9_oval.jpg     2220       1     1       6.67
# 2220  Google_1_Jennie Kissinger_15_oval.jpg     2221       0     1       6.27
# 2221        Google_1_Eileen Burd_7_oval.jpg     2222       0     1       5.86
#
# ...
