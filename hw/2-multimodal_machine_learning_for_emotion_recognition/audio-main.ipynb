# %% [markdown]
# # HW 2 Multimodal Machine Learning for Emotion Recognition
#
# - main with sub notebooks
#     1. audio (acoustic) (this notebook)
#     2. text (lexical)
#     3. visual
#
# - `%load` and `%run` with [cell magic](https://ipython.readthedocs.io/en/stable/interactive/magics.html#magic-load): This allows us to get code from another notebook

# %%
# !pip install scikit-image

# %%
main_notebook = 'main.ipynb'

# %%
# %load main_notebook
main.ipynb

# %%
# %run 'main.ipynb'

# %%
for audio_features_path in audio_features_paths:
    # print("Current path with files is: ", audio_features_path)
    path_exists = os.path.exists(audio_features_path)
    print(path_exists)
    if path_exists == True:
        print("Current path with files is: ", audio_features_path)
        load_audio_features_file = np.load(audio_features_path)
        print("  Original Shape: ", np.shape(load_audio_features_file))
        resampled_audio = librosa.resample(load_audio_features_file, orig_sr=22050, target_sr=8000)
        print("  Reduced shape: ", np.shape(resampled_audio))
        print()
    else:
        print("CANNOT find current path: ", audio_features_path)
# Out:
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro01/Ses01F_impro01_F001.npy
#   Original Shape:  (1, 128)
#   Reduced shape:  (1, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro01/Ses01F_impro01_M011.npy
#   Original Shape:  (7, 128)
#   Reduced shape:  (7, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro02/Ses01F_impro02_F002.npy
#   Original Shape:  (5, 128)
#   Reduced shape:  (5, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro02/Ses01F_impro02_F003.npy
#   Original Shape:  (5, 128)
#   Reduced shape:  (5, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro02/Ses01F_impro02_F004.npy
#   Original Shape:  (5, 128)
#   Reduced shape:  (5, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro02/Ses01F_impro02_F010.npy
#   Original Shape:  (4, 128)
#   Reduced shape:  (4, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro02/Ses01F_impro02_F014.npy
#   Original Shape:  (7, 128)
#   Reduced shape:  (7, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro02/Ses01F_impro02_F018.npy
#   Original Shape:  (3, 128)
#   Reduced shape:  (3, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro02/Ses01F_impro02_F019.npy
#   Original Shape:  (3, 128)
#   Reduced shape:  (3, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro02/Ses01F_impro02_M005.npy
#   Original Shape:  (5, 128)
#   Reduced shape:  (5, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro02/Ses01F_impro02_M011.npy
#   Original Shape:  (3, 128)
#   Reduced shape:  (3, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro02/Ses01F_impro02_M014.npy
#   Original Shape:  (4, 128)
#   Reduced shape:  (4, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro02/Ses01F_impro02_M015.npy
#   Original Shape:  (1, 128)
#   Reduced shape:  (1, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro03/Ses01F_impro03_F005.npy
#   Original Shape:  (2, 128)
#   Reduced shape:  (2, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro03/Ses01F_impro03_F006.npy
#   Original Shape:  (6, 128)
#   Reduced shape:  (6, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro03/Ses01F_impro03_F008.npy
#   Original Shape:  (2, 128)
#   Reduced shape:  (2, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro03/Ses01F_impro03_F009.npy
#   Original Shape:  (1, 128)
#   Reduced shape:  (1, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro03/Ses01F_impro03_F018.npy
#   Original Shape:  (3, 128)
#   Reduced shape:  (3, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro03/Ses01F_impro03_F021.npy
#   Original Shape:  (5, 128)
#   Reduced shape:  (5, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro03/Ses01F_impro03_F022.npy
#   Original Shape:  (2, 128)
#   Reduced shape:  (2, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro03/Ses01F_impro03_F023.npy
#   Original Shape:  (1, 128)
#   Reduced shape:  (1, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro03/Ses01F_impro03_F024.npy
#   Original Shape:  (4, 128)
#   Reduced shape:  (4, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro03/Ses01F_impro03_M006.npy
#   Original Shape:  (2, 128)
#   Reduced shape:  (2, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro03/Ses01F_impro03_M008.npy
#   Original Shape:  (1, 128)
#   Reduced shape:  (1, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro03/Ses01F_impro03_M016.npy
#   Original Shape:  (1, 128)
#   Reduced shape:  (1, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro04/Ses01F_impro04_F000.npy
#   Original Shape:  (4, 128)
#   Reduced shape:  (4, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro04/Ses01F_impro04_F028.npy
#   Original Shape:  (2, 128)
#   Reduced shape:  (2, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro04/Ses01F_impro04_M000.npy
#   Original Shape:  (4, 128)
#   Reduced shape:  (4, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro04/Ses01F_impro04_M002.npy
#   Original Shape:  (3, 128)
#   Reduced shape:  (3, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro04/Ses01F_impro04_M005.npy
#   Original Shape:  (3, 128)
#   Reduced shape:  (3, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro04/Ses01F_impro04_M007.npy
#   Original Shape:  (1, 128)
#   Reduced shape:  (1, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro04/Ses01F_impro04_M011.npy
#   Original Shape:  (3, 128)
#   Reduced shape:  (3, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro04/Ses01F_impro04_M012.npy
#   Original Shape:  (2, 128)
#   Reduced shape:  (2, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro04/Ses01F_impro04_M013.npy
#   Original Shape:  (3, 128)
#   Reduced shape:  (3, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro04/Ses01F_impro04_M014.npy
#   Original Shape:  (7, 128)
#   Reduced shape:  (7, 47)
#
# False
# CANNOT find current path:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro04/Ses01F_impro04_M016.npy
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro04/Ses01F_impro04_M017.npy
#   Original Shape:  (2, 128)
#   Reduced shape:  (2, 47)
#
# False
# CANNOT find current path:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro04/Ses01F_impro04_M019.npy
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro04/Ses01F_impro04_M020.npy
#   Original Shape:  (1, 128)
#   Reduced shape:  (1, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro04/Ses01F_impro04_M022.npy
#   Original Shape:  (2, 128)
#   Reduced shape:  (2, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro04/Ses01F_impro04_M023.npy
#   Original Shape:  (4, 128)
#   Reduced shape:  (4, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro04/Ses01F_impro04_M027.npy
#   Original Shape:  (2, 128)
#   Reduced shape:  (2, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro04/Ses01F_impro04_M028.npy
#   Original Shape:  (1, 128)
#   Reduced shape:  (1, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro04/Ses01F_impro04_M032.npy
#   Original Shape:  (2, 128)
#   Reduced shape:  (2, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro05/Ses01F_impro05_F011.npy
#   Original Shape:  (1, 128)
#   Reduced shape:  (1, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro05/Ses01F_impro05_F014.npy
#   Original Shape:  (3, 128)
#   Reduced shape:  (3, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro05/Ses01F_impro05_F015.npy
#   Original Shape:  (16, 128)
#   Reduced shape:  (16, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro05/Ses01F_impro05_F019.npy
#   Original Shape:  (5, 128)
#   Reduced shape:  (5, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro05/Ses01F_impro05_F022.npy
#   Original Shape:  (3, 128)
#   Reduced shape:  (3, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro05/Ses01F_impro05_F024.npy
#   Original Shape:  (1, 128)
#   Reduced shape:  (1, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro05/Ses01F_impro05_F030.npy
#   Original Shape:  (3, 128)
#   Reduced shape:  (3, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro05/Ses01F_impro05_M000.npy
#   Original Shape:  (1, 128)
#   Reduced shape:  (1, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro05/Ses01F_impro05_M003.npy
#   Original Shape:  (1, 128)
#   Reduced shape:  (1, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro05/Ses01F_impro05_M004.npy
#   Original Shape:  (1, 128)
#   Reduced shape:  (1, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro05/Ses01F_impro05_M006.npy
#   Original Shape:  (1, 128)
#   Reduced shape:  (1, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro05/Ses01F_impro05_M015.npy
#   Original Shape:  (3, 128)
#   Reduced shape:  (3, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro05/Ses01F_impro05_M017.npy
#   Original Shape:  (6, 128)
#   Reduced shape:  (6, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro05/Ses01F_impro05_M019.npy
#   Original Shape:  (1, 128)
#   Reduced shape:  (1, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro05/Ses01F_impro05_M024.npy
#   Original Shape:  (6, 128)
#   Reduced shape:  (6, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro05/Ses01F_impro05_M026.npy
#   Original Shape:  (5, 128)
#   Reduced shape:  (5, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro05/Ses01F_impro05_M027.npy
#   Original Shape:  (1, 128)
#   Reduced shape:  (1, 47)
#
# False
# CANNOT find current path:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro05/Ses01F_impro05_M028.npy
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro05/Ses01F_impro05_M030.npy
#   Original Shape:  (4, 128)
#   Reduced shape:  (4, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro05/Ses01F_impro05_M035.npy
#   Original Shape:  (6, 128)
#   Reduced shape:  (6, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro06/Ses01F_impro06_F004.npy
#   Original Shape:  (2, 128)
#   Reduced shape:  (2, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro06/Ses01F_impro06_F007.npy
#   Original Shape:  (8, 128)
#   Reduced shape:  (8, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro06/Ses01F_impro06_F015.npy
#   Original Shape:  (3, 128)
#   Reduced shape:  (3, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro06/Ses01F_impro06_F016.npy
#   Original Shape:  (7, 128)
#   Reduced shape:  (7, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro06/Ses01F_impro06_F018.npy
#   Original Shape:  (7, 128)
#   Reduced shape:  (7, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro06/Ses01F_impro06_F021.npy
#   Original Shape:  (17, 128)
#   Reduced shape:  (17, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro06/Ses01F_impro06_F022.npy
#   Original Shape:  (5, 128)
#   Reduced shape:  (5, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro06/Ses01F_impro06_F023.npy
#   Original Shape:  (4, 128)
#   Reduced shape:  (4, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro06/Ses01F_impro06_F024.npy
#   Original Shape:  (7, 128)
#   Reduced shape:  (7, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro06/Ses01F_impro06_F026.npy
#   Original Shape:  (9, 128)
#   Reduced shape:  (9, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro06/Ses01F_impro06_M000.npy
#   Original Shape:  (3, 128)
#   Reduced shape:  (3, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro06/Ses01F_impro06_M005.npy
#   Original Shape:  (1, 128)
#   Reduced shape:  (1, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro06/Ses01F_impro06_M006.npy
#   Original Shape:  (1, 128)
#   Reduced shape:  (1, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro06/Ses01F_impro06_M008.npy
#   Original Shape:  (2, 128)
#   Reduced shape:  (2, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro06/Ses01F_impro06_M010.npy
#   Original Shape:  (1, 128)
#   Reduced shape:  (1, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro06/Ses01F_impro06_M011.npy
#   Original Shape:  (3, 128)
#   Reduced shape:  (3, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro06/Ses01F_impro06_M012.npy
#   Original Shape:  (2, 128)
#   Reduced shape:  (2, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro06/Ses01F_impro06_M016.npy
#   Original Shape:  (3, 128)
#   Reduced shape:  (3, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro07/Ses01F_impro07_M013.npy
#   Original Shape:  (3, 128)
#   Reduced shape:  (3, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_impro07/Ses01F_impro07_M019.npy
#   Original Shape:  (13, 128)
#   Reduced shape:  (13, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script01_1/Ses01F_script01_1_F015.npy
#   Original Shape:  (4, 128)
#   Reduced shape:  (4, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script01_1/Ses01F_script01_1_F041.npy
#   Original Shape:  (10, 128)
#   Reduced shape:  (10, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script01_1/Ses01F_script01_1_F042.npy
#   Original Shape:  (3, 128)
#   Reduced shape:  (3, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script01_1/Ses01F_script01_1_M001.npy
#   Original Shape:  (3, 128)
#   Reduced shape:  (3, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script01_1/Ses01F_script01_1_M002.npy
#   Original Shape:  (11, 128)
#   Reduced shape:  (11, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script01_1/Ses01F_script01_1_M010.npy
#   Original Shape:  (2, 128)
#   Reduced shape:  (2, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script01_1/Ses01F_script01_1_M015.npy
#   Original Shape:  (3, 128)
#   Reduced shape:  (3, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script01_1/Ses01F_script01_1_M017.npy
#   Original Shape:  (3, 128)
#   Reduced shape:  (3, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script01_1/Ses01F_script01_1_M019.npy
#   Original Shape:  (10, 128)
#   Reduced shape:  (10, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script01_1/Ses01F_script01_1_M024.npy
#   Original Shape:  (10, 128)
#   Reduced shape:  (10, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script01_1/Ses01F_script01_1_M034.npy
#   Original Shape:  (5, 128)
#   Reduced shape:  (5, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script01_1/Ses01F_script01_1_M039.npy
#   Original Shape:  (2, 128)
#   Reduced shape:  (2, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script01_2/Ses01F_script01_2_F007.npy
#   Original Shape:  (9, 128)
#   Reduced shape:  (9, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script01_2/Ses01F_script01_2_F008.npy
#   Original Shape:  (11, 128)
#   Reduced shape:  (11, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script01_2/Ses01F_script01_2_F009.npy
#   Original Shape:  (9, 128)
#   Reduced shape:  (9, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script01_2/Ses01F_script01_2_F012.npy
#   Original Shape:  (14, 128)
#   Reduced shape:  (14, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script01_2/Ses01F_script01_2_F013.npy
#   Original Shape:  (10, 128)
#   Reduced shape:  (10, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script01_2/Ses01F_script01_2_M001.npy
#   Original Shape:  (5, 128)
#   Reduced shape:  (5, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script01_2/Ses01F_script01_2_M004.npy
#   Original Shape:  (2, 128)
#   Reduced shape:  (2, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script01_3/Ses01F_script01_3_F002.npy
#   Original Shape:  (9, 128)
#   Reduced shape:  (9, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script01_3/Ses01F_script01_3_F007.npy
#   Original Shape:  (2, 128)
#   Reduced shape:  (2, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script01_3/Ses01F_script01_3_F011.npy
#   Original Shape:  (2, 128)
#   Reduced shape:  (2, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script01_3/Ses01F_script01_3_F012.npy
#   Original Shape:  (5, 128)
#   Reduced shape:  (5, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script01_3/Ses01F_script01_3_F014.npy
#   Original Shape:  (5, 128)
#   Reduced shape:  (5, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script01_3/Ses01F_script01_3_F019.npy
#   Original Shape:  (2, 128)
#   Reduced shape:  (2, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script01_3/Ses01F_script01_3_M000.npy
#   Original Shape:  (4, 128)
#   Reduced shape:  (4, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script01_3/Ses01F_script01_3_M009.npy
#   Original Shape:  (8, 128)
#   Reduced shape:  (8, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script01_3/Ses01F_script01_3_M010.npy
#   Original Shape:  (11, 128)
#   Reduced shape:  (11, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script01_3/Ses01F_script01_3_M019.npy
#   Original Shape:  (5, 128)
#   Reduced shape:  (5, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script01_3/Ses01F_script01_3_M027.npy
#   Original Shape:  (2, 128)
#   Reduced shape:  (2, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script01_3/Ses01F_script01_3_M033.npy
#   Original Shape:  (18, 128)
#   Reduced shape:  (18, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script02_1/Ses01F_script02_1_F006.npy
#   Original Shape:  (3, 128)
#   Reduced shape:  (3, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script02_1/Ses01F_script02_1_F008.npy
#   Original Shape:  (1, 128)
#   Reduced shape:  (1, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script02_1/Ses01F_script02_1_F009.npy
#   Original Shape:  (1, 128)
#   Reduced shape:  (1, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script02_1/Ses01F_script02_1_M007.npy
#   Original Shape:  (3, 128)
#   Reduced shape:  (3, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script02_1/Ses01F_script02_1_M014.npy
#   Original Shape:  (10, 128)
#   Reduced shape:  (10, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script02_1/Ses01F_script02_1_M020.npy
#   Original Shape:  (1, 128)
#   Reduced shape:  (1, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script02_1/Ses01F_script02_1_M043.npy
#   Original Shape:  (3, 128)
#   Reduced shape:  (3, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script02_1/Ses01F_script02_1_M044.npy
#   Original Shape:  (3, 128)
#   Reduced shape:  (3, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script02_2/Ses01F_script02_2_F000.npy
#   Original Shape:  (2, 128)
#   Reduced shape:  (2, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script02_2/Ses01F_script02_2_F006.npy
#   Original Shape:  (6, 128)
#   Reduced shape:  (6, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script02_2/Ses01F_script02_2_F008.npy
#   Original Shape:  (6, 128)
#   Reduced shape:  (6, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script02_2/Ses01F_script02_2_F009.npy
#   Original Shape:  (4, 128)
#   Reduced shape:  (4, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script02_2/Ses01F_script02_2_F010.npy
#   Original Shape:  (3, 128)
#   Reduced shape:  (3, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script02_2/Ses01F_script02_2_F015.npy
#   Original Shape:  (10, 128)
#   Reduced shape:  (10, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script02_2/Ses01F_script02_2_F016.npy
#   Original Shape:  (3, 128)
#   Reduced shape:  (3, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script02_2/Ses01F_script02_2_F017.npy
#   Original Shape:  (7, 128)
#   Reduced shape:  (7, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script02_2/Ses01F_script02_2_F035.npy
#   Original Shape:  (14, 128)
#   Reduced shape:  (14, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script02_2/Ses01F_script02_2_F036.npy
#   Original Shape:  (2, 128)
#   Reduced shape:  (2, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script02_2/Ses01F_script02_2_F042.npy
#   Original Shape:  (6, 128)
#   Reduced shape:  (6, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script02_2/Ses01F_script02_2_F044.npy
#   Original Shape:  (2, 128)
#   Reduced shape:  (2, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script02_2/Ses01F_script02_2_M006.npy
#   Original Shape:  (7, 128)
#   Reduced shape:  (7, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script02_2/Ses01F_script02_2_M017.npy
#   Original Shape:  (5, 128)
#   Reduced shape:  (5, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script02_2/Ses01F_script02_2_M026.npy
#   Original Shape:  (4, 128)
#   Reduced shape:  (4, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script02_2/Ses01F_script02_2_M038.npy
#   Original Shape:  (3, 128)
#   Reduced shape:  (3, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script02_2/Ses01F_script02_2_M040.npy
#   Original Shape:  (7, 128)
#   Reduced shape:  (7, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script02_2/Ses01F_script02_2_M042.npy
#   Original Shape:  (4, 128)
#   Reduced shape:  (4, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script02_2/Ses01F_script02_2_M043.npy
#   Original Shape:  (1, 128)
#   Reduced shape:  (1, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script02_2/Ses01F_script02_2_M048.npy
#   Original Shape:  (7, 128)
#   Reduced shape:  (7, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script03_1/Ses01F_script03_1_F010.npy
#   Original Shape:  (2, 128)
#   Reduced shape:  (2, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script03_1/Ses01F_script03_1_F020.npy
#   Original Shape:  (4, 128)
#   Reduced shape:  (4, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script03_1/Ses01F_script03_1_M010.npy
#   Original Shape:  (8, 128)
#   Reduced shape:  (8, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script03_1/Ses01F_script03_1_M018.npy
#   Original Shape:  (2, 128)
#   Reduced shape:  (2, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script03_1/Ses01F_script03_1_M025.npy
#   Original Shape:  (7, 128)
#   Reduced shape:  (7, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script03_1/Ses01F_script03_1_M026.npy
#   Original Shape:  (17, 128)
#   Reduced shape:  (17, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script03_1/Ses01F_script03_1_M034.npy
#   Original Shape:  (4, 128)
#   Reduced shape:  (4, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script03_2/Ses01F_script03_2_F001.npy
#   Original Shape:  (4, 128)
#   Reduced shape:  (4, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script03_2/Ses01F_script03_2_F005.npy
#   Original Shape:  (2, 128)
#   Reduced shape:  (2, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script03_2/Ses01F_script03_2_F013.npy
#   Original Shape:  (2, 128)
#   Reduced shape:  (2, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script03_2/Ses01F_script03_2_F014.npy
#   Original Shape:  (2, 128)
#   Reduced shape:  (2, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script03_2/Ses01F_script03_2_F015.npy
#   Original Shape:  (4, 128)
#   Reduced shape:  (4, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script03_2/Ses01F_script03_2_F018.npy
#   Original Shape:  (1, 128)
#   Reduced shape:  (1, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script03_2/Ses01F_script03_2_F021.npy
#   Original Shape:  (8, 128)
#   Reduced shape:  (8, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script03_2/Ses01F_script03_2_F024.npy
#   Original Shape:  (4, 128)
#   Reduced shape:  (4, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script03_2/Ses01F_script03_2_F031.npy
#   Original Shape:  (3, 128)
#   Reduced shape:  (3, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script03_2/Ses01F_script03_2_F035.npy
#   Original Shape:  (4, 128)
#   Reduced shape:  (4, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script03_2/Ses01F_script03_2_F040.npy
#   Original Shape:  (19, 128)
#   Reduced shape:  (19, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script03_2/Ses01F_script03_2_M020.npy
#   Original Shape:  (5, 128)
#   Reduced shape:  (5, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script03_2/Ses01F_script03_2_M021.npy
#   Original Shape:  (3, 128)
#   Reduced shape:  (3, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script03_2/Ses01F_script03_2_M023.npy
#   Original Shape:  (3, 128)
#   Reduced shape:  (3, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script03_2/Ses01F_script03_2_M024.npy
#   Original Shape:  (13, 128)
#   Reduced shape:  (13, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script03_2/Ses01F_script03_2_M030.npy
#   Original Shape:  (2, 128)
#   Reduced shape:  (2, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script03_2/Ses01F_script03_2_M032.npy
#   Original Shape:  (3, 128)
#   Reduced shape:  (3, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script03_2/Ses01F_script03_2_M033.npy
#   Original Shape:  (5, 128)
#   Reduced shape:  (5, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script03_2/Ses01F_script03_2_M034.npy
#   Original Shape:  (3, 128)
#   Reduced shape:  (3, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script03_2/Ses01F_script03_2_M036.npy
#   Original Shape:  (4, 128)
#   Reduced shape:  (4, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01F_script03_2/Ses01F_script03_2_M037.npy
#   Original Shape:  (9, 128)
#   Reduced shape:  (9, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01M_impro01/Ses01M_impro01_F001.npy
#   Original Shape:  (2, 128)
#   Reduced shape:  (2, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01M_impro01/Ses01M_impro01_F007.npy
#   Original Shape:  (3, 128)
#   Reduced shape:  (3, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01M_impro01/Ses01M_impro01_F011.npy
#   Original Shape:  (2, 128)
#   Reduced shape:  (2, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01M_impro01/Ses01M_impro01_F019.npy
#   Original Shape:  (3, 128)
#   Reduced shape:  (3, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01M_impro01/Ses01M_impro01_F022.npy
#   Original Shape:  (11, 128)
#   Reduced shape:  (11, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session1/Ses01M_impro01/Ses01M_impro01_M003.npy
#   Original Shape:  (2, 128)
# ...
#   Reduced shape:  (6, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script01_1/Ses05M_script01_1_F021.npy
#   Original Shape:  (3, 128)
#   Reduced shape:  (3, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script01_1/Ses05M_script01_1_F022.npy
#   Original Shape:  (15, 128)
#   Reduced shape:  (15, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script01_1/Ses05M_script01_1_F032.npy
#   Original Shape:  (1, 128)
#   Reduced shape:  (1, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script01_1/Ses05M_script01_1_F035.npy
#   Original Shape:  (6, 128)
#   Reduced shape:  (6, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script01_1/Ses05M_script01_1_M025.npy
#   Original Shape:  (2, 128)
#   Reduced shape:  (2, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script01_1/Ses05M_script01_1_M028.npy
#   Original Shape:  (3, 128)
#   Reduced shape:  (3, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script01_1/Ses05M_script01_1_M035.npy
#   Original Shape:  (5, 128)
#   Reduced shape:  (5, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script01_1b/Ses05M_script01_1b_F023.npy
#   Original Shape:  (4, 128)
#   Reduced shape:  (4, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script01_1b/Ses05M_script01_1b_F028.npy
#   Original Shape:  (7, 128)
#   Reduced shape:  (7, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script01_1b/Ses05M_script01_1b_M031.npy
#   Original Shape:  (11, 128)
#   Reduced shape:  (11, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script01_1b/Ses05M_script01_1b_M033.npy
#   Original Shape:  (6, 128)
#   Reduced shape:  (6, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script01_1b/Ses05M_script01_1b_M041.npy
#   Original Shape:  (4, 128)
#   Reduced shape:  (4, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script01_2/Ses05M_script01_2_F015.npy
#   Original Shape:  (3, 128)
#   Reduced shape:  (3, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script01_2/Ses05M_script01_2_M001.npy
#   Original Shape:  (5, 128)
#   Reduced shape:  (5, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script01_3/Ses05M_script01_3_F009.npy
#   Original Shape:  (3, 128)
#   Reduced shape:  (3, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script01_3/Ses05M_script01_3_F023.npy
#   Original Shape:  (1, 128)
#   Reduced shape:  (1, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script01_3/Ses05M_script01_3_F024.npy
#   Original Shape:  (2, 128)
#   Reduced shape:  (2, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script01_3/Ses05M_script01_3_M019.npy
#   Original Shape:  (4, 128)
#   Reduced shape:  (4, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script01_3/Ses05M_script01_3_M022.npy
#   Original Shape:  (2, 128)
#   Reduced shape:  (2, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script01_3/Ses05M_script01_3_M030.npy
#   Original Shape:  (13, 128)
#   Reduced shape:  (13, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script02_1/Ses05M_script02_1_F001.npy
#   Original Shape:  (1, 128)
#   Reduced shape:  (1, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script02_1/Ses05M_script02_1_F016.npy
#   Original Shape:  (1, 128)
#   Reduced shape:  (1, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script02_2/Ses05M_script02_2_F000.npy
#   Original Shape:  (1, 128)
#   Reduced shape:  (1, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script02_2/Ses05M_script02_2_F009.npy
#   Original Shape:  (2, 128)
#   Reduced shape:  (2, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script02_2/Ses05M_script02_2_F010.npy
#   Original Shape:  (17, 128)
#   Reduced shape:  (17, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script02_2/Ses05M_script02_2_F012.npy
#   Original Shape:  (8, 128)
#   Reduced shape:  (8, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script02_2/Ses05M_script02_2_F014.npy
#   Original Shape:  (10, 128)
#   Reduced shape:  (10, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script02_2/Ses05M_script02_2_F017.npy
#   Original Shape:  (1, 128)
#   Reduced shape:  (1, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script02_2/Ses05M_script02_2_F019.npy
#   Original Shape:  (1, 128)
#   Reduced shape:  (1, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script02_2/Ses05M_script02_2_F023.npy
#   Original Shape:  (4, 128)
#   Reduced shape:  (4, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script02_2/Ses05M_script02_2_F031.npy
#   Original Shape:  (6, 128)
#   Reduced shape:  (6, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script02_2/Ses05M_script02_2_F034.npy
#   Original Shape:  (9, 128)
#   Reduced shape:  (9, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script02_2/Ses05M_script02_2_F038.npy
#   Original Shape:  (2, 128)
#   Reduced shape:  (2, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script02_2/Ses05M_script02_2_M005.npy
#   Original Shape:  (9, 128)
#   Reduced shape:  (9, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script02_2/Ses05M_script02_2_M026.npy
#   Original Shape:  (5, 128)
#   Reduced shape:  (5, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script02_2/Ses05M_script02_2_M031.npy
#   Original Shape:  (3, 128)
#   Reduced shape:  (3, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script02_2/Ses05M_script02_2_M032.npy
#   Original Shape:  (4, 128)
#   Reduced shape:  (4, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script02_2/Ses05M_script02_2_M034.npy
#   Original Shape:  (7, 128)
#   Reduced shape:  (7, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script02_2/Ses05M_script02_2_M040.npy
#   Original Shape:  (2, 128)
#   Reduced shape:  (2, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script03_1/Ses05M_script03_1_F020.npy
#   Original Shape:  (2, 128)
#   Reduced shape:  (2, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script03_2/Ses05M_script03_2_F006.npy
#   Original Shape:  (3, 128)
#   Reduced shape:  (3, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script03_2/Ses05M_script03_2_F012.npy
#   Original Shape:  (2, 128)
#   Reduced shape:  (2, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script03_2/Ses05M_script03_2_F017.npy
#   Original Shape:  (1, 128)
#   Reduced shape:  (1, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script03_2/Ses05M_script03_2_F034.npy
#   Original Shape:  (4, 128)
#   Reduced shape:  (4, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script03_2/Ses05M_script03_2_F035.npy
#   Original Shape:  (3, 128)
#   Reduced shape:  (3, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script03_2/Ses05M_script03_2_F037.npy
#   Original Shape:  (5, 128)
#   Reduced shape:  (5, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script03_2/Ses05M_script03_2_F044.npy
#   Original Shape:  (1, 128)
#   Reduced shape:  (1, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script03_2/Ses05M_script03_2_M015.npy
#   Original Shape:  (2, 128)
#   Reduced shape:  (2, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script03_2/Ses05M_script03_2_M024.npy
#   Original Shape:  (6, 128)
#   Reduced shape:  (6, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script03_2/Ses05M_script03_2_M025.npy
#   Original Shape:  (4, 128)
#   Reduced shape:  (4, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script03_2/Ses05M_script03_2_M026.npy
#   Original Shape:  (7, 128)
#   Reduced shape:  (7, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script03_2/Ses05M_script03_2_M027.npy
#   Original Shape:  (3, 128)
#   Reduced shape:  (3, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script03_2/Ses05M_script03_2_M028.npy
#   Original Shape:  (8, 128)
#   Reduced shape:  (8, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script03_2/Ses05M_script03_2_M029.npy
#   Original Shape:  (4, 128)
#   Reduced shape:  (4, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script03_2/Ses05M_script03_2_M039.npy
#   Original Shape:  (2, 128)
#   Reduced shape:  (2, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script03_2/Ses05M_script03_2_M041.npy
#   Original Shape:  (8, 128)
#   Reduced shape:  (8, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script03_2/Ses05M_script03_2_M042.npy
#   Original Shape:  (1, 128)
#   Reduced shape:  (1, 47)
#
# True
# Current path with files is:  /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/hw_2/features/acoustic_features/Session5/Ses05M_script03_2/Ses05M_script03_2_M043.npy
#   Original Shape:  (2, 128)
#   Reduced shape:  (2, 47)
