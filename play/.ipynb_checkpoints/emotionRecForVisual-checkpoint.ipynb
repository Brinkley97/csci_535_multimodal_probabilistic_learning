# %% [markdown]
# # Emotion Recognition for Visual

# %%
import os
import pandas as pd

# %%
BASE = "/Users/brinkley97/Documents/development/"
CLASS_PATH = "classes/csci_535_multimodal_probabilistic_learning/"
DATASET_PATH = "datasets/msp/videos/"
VIDEO_FILES = "full_r_and_t_mspVideoPaths.csv"
video_file_paths = BASE + CLASS_PATH + DATASET_PATH + VIDEO_FILES

r_frames = "r_videos/"
r_frames_files = BASE + CLASS_PATH + DATASET_PATH + r_frames

# %%
def load_data(file):
    original_data = pd.read_csv(file)
    # original_data = pd.DataFrame(file)
    copy_of_data = original_data.copy()
    return copy_of_data

# %%
# 4 classes - anger, happiness, neutral, sadness
# dataset_paths_copy = load_data(video_file_paths)
# dataset_paths_copy

# %%
def get_frames(folder_exists, r_video_path):
    """
    """
    print(r_video_path)
    list_frames = os.listdir(r_video_path)
    print(list_frames)
    print()

# %%
r_videos = os.listdir(r_frames_files)
# r_videos

# %%
for r_video in r_videos:
    r_video_path = r_frames_files + r_video
    folder_exists = os.path.isdir(r_video_path)
    if folder_exists == True:
        # print(folder_exists, r_video_path)
        get_frames(folder_exists, r_video_path)
    else: 
        # print(False)
        pass
# Out:
# /Users/brinkley97/Documents/development/classes/csci_535_multimodal_probabilistic_learning/datasets/msp/videos/r_videos/MSP-IMPROV-S07A-F03-R-FF01_frames
# ...

# %%
# anger_files_df = dataset_paths_copy.loc[0:, "A"]
# anger_files_df = anger_files_df.dropna()
# anger_files = list(anger_files_df)
# anger_files
